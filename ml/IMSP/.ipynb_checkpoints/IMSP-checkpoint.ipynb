# %% [markdown]
# # PRACTICAL WORK
# ********************
# ********************
# ********************
# Proposed by
#
# __CARLYNA BONDIOMBOUY__
#
#
# ********************
# ********************
# ********************
#
#
# The practical work enables to become familiar with Spark distributed data framework. To sit the different concepts list during the courses. We divide the practical work in two parts : Basic exercise and advanced exercise.
#
# 1. Basic exercise: concerns Word count, we will manipulate the content of the file contained in the directory /tmp/TP_Spark by working with Spark data model.
#
# 2. Advanced exercise: based on the forum web application scenario. The motivate example, enables to help an editorial ofice to find appropriate reporters for a list of publications based on given keywords.
#
#
# ***
#
# #### Source : Spark/Python Practice. Boyan Kolev, Patrick Valduriez and Esther Pacitti
#
# ***
#
# ### Basic Exercise
#
# Now, let us extend in a more practical way the *“word count”* example from the previous section. We will read data from numerous text files, count the word occurrences, and save the results as text files.
#
#  Let us assume that */tmp/TP_Spark* is our working directory. In the data set, you will find a subdirectory named *spark-docs* containing the Spark documentation in *.md files.*
#
#  You have to use *SparkContext’s textFile* method, that reads one or more text files and creates an RDD, where each element is one line of the text file(s). The argument of the function is the path to the file(s) and it accepts wildcards, so that you can read at once all the *.md* files in the *spark-docs* directory.
#
# Then, transform the resulting RDD (where each element is a whole line) to into a new *wordsRDD*, where each element is a single word. For the purpose, use the *flatMap* operation, which allows for a single RDD element to be transformed into multiple elements in the returned RDD.
#
# The *flatMap* transformation function should return a collection instead of a single value; like in the previous example, use space as a delimiter to split a line into words. Then, use the same map and *reduceByKey* operations as in the previous example to create the *wordCount* final RDD and save it as text into */tmp/TP_Spark/output.*
#
# Note that *saveAsTextFile* creates the directory specified with the argument and creates many files named *part-XXXXX* that correspond to the partitions of the final RDD. It also requires that the destination directory do not exist, so if you rerun this example, make sure to delete the *output* directory.
#
# __Solution:__

# %%
from pyspark import  SparkContext
sc = SparkContext.getOrCreate()
#sc = SparkContext("local", "App")

#sc = SparkContext(appName = "check")
RDread = sc.textFile ("C:/Users/carlyna.bondiombouy/Desktop/tmp - Copie/spark-docs/*.md")
RDread.collect()
# Out:
# ['---',
#  'layout: global',
#  'title: Spark API Documentation',
#  '---',
#  '',
#  'Here you can read API docs for Spark and its submodules.',
#  '',
#  '- [Spark Scala API (Scaladoc)](api/scala/index.html)',
#  '- [Spark Java API (Javadoc)](api/java/index.html)',
#  '- [Spark Python API (Sphinx)](api/python/index.html)',
#  '- [Spark R API (Roxygen2)](api/R/index.html)',
#  '',
#  '---',
#  'layout: global',
#  'title: Building Spark',
#  'redirect_from: "building-with-maven.html"',
#  '---',
#  '',
#  '* This will become a table of contents (this text will be scraped).',
#  '{:toc}',
#  '',
#  '# Building Apache Spark',
#  '',
#  '## Apache Maven',
#  '',
#  'The Maven-based build is the build of reference for Apache Spark.',
#  'Building Spark using Maven requires Maven 3.3.9 or newer and Java 8+.',
#  'Note that support for Java 7 was removed as of Spark 2.2.0.',
#  '',
#  "### Setting up Maven's Memory Usage",
#  '',
#  "You'll need to configure Maven to use more memory than usual by setting `MAVEN_OPTS`:",
#  '',
#  '    export MAVEN_OPTS="-Xmx2g -XX:ReservedCodeCacheSize=512m"',
#  '',
#  '(The `ReservedCodeCacheSize` setting is optional but recommended.)',
#  "If you don't add these parameters to `MAVEN_OPTS`, you may see errors and warnings like the following:",
#  '',
#  '    [INFO] Compiling 203 Scala sources and 9 Java sources to /Users/me/Development/spark/core/target/scala-{{site.SCALA_BINARY_VERSION}}/classes...',
#  '    [ERROR] Java heap space -> [Help 1]',
#  '',
#  'You can fix these problems by setting the `MAVEN_OPTS` variable as discussed before.',
#  '',
#  '**Note:**',
#  '',
#  '* If using `build/mvn` with no `MAVEN_OPTS` set, the script will automatically add the above options to the `MAVEN_OPTS` environment variable.',
#  '* The `test` phase of the Spark build will automatically add these options to `MAVEN_OPTS`, even when not using `build/mvn`.    ',
#  '',
#  '### build/mvn',
#  '',
#  'Spark now comes packaged with a self-contained Maven installation to ease building and deployment of Spark from source located under the `build/` directory. This script will automatically download and setup all necessary build requirements ([Maven](https://maven.apache.org/), [Scala](http://www.scala-lang.org/), and [Zinc](https://github.com/typesafehub/zinc)) locally within the `build/` directory itself. It honors any `mvn` binary if present already, however, will pull down its own copy of Scala and Zinc regardless to ensure proper version requirements are met. `build/mvn` execution acts as a pass through to the `mvn` call allowing easy transition from previous build methods. As an example, one can build a version of Spark as follows:',
#  '',
#  '    ./build/mvn -DskipTests clean package',
#  '',
#  'Other build examples can be found below.',
#  '',
#  '## Building a Runnable Distribution',
#  '',
#  'To create a Spark distribution like those distributed by the',
#  '[Spark Downloads](http://spark.apache.org/downloads.html) page, and that is laid out so as',
#  'to be runnable, use `./dev/make-distribution.sh` in the project root directory. It can be configured',
#  'with Maven profile settings and so on like the direct Maven build. Example:',
#  '',
#  '    ./dev/make-distribution.sh --name custom-spark --pip --r --tgz -Psparkr -Phadoop-2.7 -Phive -Phive-thriftserver -Pmesos -Pyarn',
#  '',
#  'This will build Spark distribution along with Python pip and R packages. For more information on usage, run `./dev/make-distribution.sh --help`',
#  '',
#  '## Specifying the Hadoop Version and Enabling YARN',
#  '',
#  'You can specify the exact version of Hadoop to compile against through the `hadoop.version` property. ',
#  'If unset, Spark will build against Hadoop 2.6.X by default.',
#  '',
#  'You can enable the `yarn` profile and optionally set the `yarn.version` property if it is different ',
#  'from `hadoop.version`.',
#  '',
#  'Examples:',
#  '',
#  '    # Apache Hadoop 2.6.X',
#  '    ./build/mvn -Pyarn -DskipTests clean package',
#  '',
#  '    # Apache Hadoop 2.7.X and later',
#  '    ./build/mvn -Pyarn -Phadoop-2.7 -Dhadoop.version=2.7.3 -DskipTests clean package',
#  '',
#  '## Building With Hive and JDBC Support',
#  '',
#  'To enable Hive integration for Spark SQL along with its JDBC server and CLI,',
#  'add the `-Phive` and `Phive-thriftserver` profiles to your existing build options.',
#  'By default Spark will build with Hive 1.2.1 bindings.',
#  '',
#  '    # With Hive 1.2.1 support',
#  '    ./build/mvn -Pyarn -Phive -Phive-thriftserver -DskipTests clean package',
#  '',
#  '## Packaging without Hadoop Dependencies for YARN',
#  '',
#  "The assembly directory produced by `mvn package` will, by default, include all of Spark's",
#  'dependencies, including Hadoop and some of its ecosystem projects. On YARN deployments, this',
#  'causes multiple versions of these to appear on executor classpaths: the version packaged in',
#  'the Spark assembly and the version on each node, included with `yarn.application.classpath`.',
#  'The `hadoop-provided` profile builds the assembly without including Hadoop-ecosystem projects,',
#  'like ZooKeeper and Hadoop itself.',
#  '',
#  '## Building with Mesos support',
#  '',
#  '    ./build/mvn -Pmesos -DskipTests clean package',
#  '',
#  '## Building for Scala 2.10',
#  'To produce a Spark package compiled with Scala 2.10, use the `-Dscala-2.10` property:',
#  '',
#  '    ./dev/change-scala-version.sh 2.10',
#  '    ./build/mvn -Pyarn -Dscala-2.10 -DskipTests clean package',
#  '',
#  'Note that support for Scala 2.10 is deprecated as of Spark 2.1.0 and may be removed in Spark 2.2.0.',
#  '',
#  '## Building submodules individually',
#  '',
#  "It's possible to build Spark sub-modules using the `mvn -pl` option.",
#  '',
#  'For instance, you can build the Spark Streaming module using:',
#  '',
#  '    ./build/mvn -pl :spark-streaming_2.11 clean install',
#  '',
#  'where `spark-streaming_2.11` is the `artifactId` as defined in `streaming/pom.xml` file.',
#  '',
#  '## Continuous Compilation',
#  '',
#  'We use the scala-maven-plugin which supports incremental and continuous compilation. E.g.',
#  '',
#  '    ./build/mvn scala:cc',
#  '',
#  'should run continuous compilation (i.e. wait for changes). However, this has not been tested',
#  'extensively. A couple of gotchas to note:',
#  '',
#  '* it only scans the paths `src/main` and `src/test` (see',
#  '[docs](http://scala-tools.org/mvnsites/maven-scala-plugin/usage_cc.html)), so it will only work',
#  'from within certain submodules that have that structure.',
#  '',
#  "* you'll typically need to run `mvn install` from the project root for compilation within",
#  'specific submodules to work; this is because submodules that depend on other submodules do so via',
#  'the `spark-parent` module).',
#  '',
#  'Thus, the full flow for running continuous-compilation of the `core` submodule may look more like:',
#  '',
#  '    $ ./build/mvn install',
#  '    $ cd core',
#  '    $ ../build/mvn scala:cc',
#  '',
#  '## Building with SBT',
#  '',
#  'Maven is the official build tool recommended for packaging Spark, and is the *build of reference*.',
#  'But SBT is supported for day-to-day development since it can provide much faster iterative',
#  'compilation. More advanced developers may wish to use SBT.',
#  '',
#  'The SBT build is derived from the Maven POM files, and so the same Maven profiles and variables',
#  'can be set to control the SBT build. For example:',
#  '',
#  '    ./build/sbt package',
#  '',
#  'To avoid the overhead of launching sbt each time you need to re-compile, you can launch sbt',
#  'in interactive mode by running `build/sbt`, and then run all build commands at the command',
#  'prompt.',
#  '',
#  '## Speeding up Compilation',
#  '',
#  'Developers who compile Spark frequently may want to speed up compilation; e.g., by using Zinc',
#  '(for developers who build with Maven) or by avoiding re-compilation of the assembly JAR (for',
#  'developers who build with SBT).  For more information about how to do this, refer to the',
#  '[Useful Developer Tools page](http://spark.apache.org/developer-tools.html#reducing-build-times).',
#  '',
#  '## Encrypted Filesystems',
#  '',
#  'When building on an encrypted filesystem (if your home directory is encrypted, for example), then the Spark build might fail with a "Filename too long" error. As a workaround, add the following in the configuration args of the `scala-maven-plugin` in the project `pom.xml`:',
#  '',
#  '    <arg>-Xmax-classfile-name</arg>',
#  '    <arg>128</arg>',
#  '',
#  'and in `project/SparkBuild.scala` add:',
#  '',
#  '    scalacOptions in Compile ++= Seq("-Xmax-classfile-name", "128"),',
#  '',
#  'to the `sharedSettings` val. See also [this PR](https://github.com/apache/spark/pull/2883/files) if you are unsure of where to add these lines.',
#  '',
#  '## IntelliJ IDEA or Eclipse',
#  '',
#  'For help in setting up IntelliJ IDEA or Eclipse for Spark development, and troubleshooting, refer to the',
#  '[Useful Developer Tools page](http://spark.apache.org/developer-tools.html).',
#  '',
#  '',
#  '# Running Tests',
#  '',
#  'Tests are run by default via the [ScalaTest Maven plugin](http://www.scalatest.org/user_guide/using_the_scalatest_maven_plugin).',
#  'Note that tests should not be run as root or an admin user.',
#  '',
#  'The following is an example of a command to run the tests:',
#  '',
#  '    ./build/mvn test',
#  '',
#  '## Testing with SBT',
#  '',
#  'The following is an example of a command to run the tests:',
#  '',
#  '    ./build/sbt test',
#  '',
#  '## Running Individual Tests',
#  '',
#  'For information about how to run individual tests, refer to the',
#  '[Useful Developer Tools page](http://spark.apache.org/developer-tools.html#running-individual-tests).',
#  '',
#  '## PySpark pip installable',
#  '',
#  'If you are building Spark for use in a Python environment and you wish to pip install it, you will first need to build the Spark JARs as described above. Then you can construct an sdist package suitable for setup.py and pip installable package.',
#  '',
#  '    cd python; python setup.py sdist',
#  '',
#  '**Note:** Due to packaging requirements you can not directly pip install from the Python directory, rather you must first build the sdist package as described above.',
#  '',
#  'Alternatively, you can also run make-distribution with the --pip option.',
#  '',
#  '## PySpark Tests with Maven',
#  '',
#  'If you are building PySpark and wish to run the PySpark tests you will need to build Spark with Hive support.',
#  '',
#  '    ./build/mvn -DskipTests clean package -Phive',
#  '    ./python/run-tests',
#  '',
#  'The run-tests script also can be limited to a specific Python version or a specific module',
#  '',
#  '    ./python/run-tests --python-executables=python --modules=pyspark-sql',
#  '',
#  '**Note:** You can also run Python tests with an sbt build, provided you build Spark with Hive support.',
#  '',
#  '## Running R Tests',
#  '',
#  'To run the SparkR tests you will need to install the [knitr](https://cran.r-project.org/package=knitr), [rmarkdown](https://cran.r-project.org/package=rmarkdown), [testthat](https://cran.r-project.org/package=testthat), [e1071](https://cran.r-project.org/package=e1071) and [survival](https://cran.r-project.org/package=survival) packages first:',
#  '',
#  '    R -e "install.packages(c(\'knitr\', \'rmarkdown\', \'testthat\', \'e1071\', \'survival\'), repos=\'http://cran.us.r-project.org\')"',
#  '',
#  'You can run just the SparkR tests using the command:',
#  '',
#  '    ./R/run-tests.sh',
#  '',
#  '## Running Docker-based Integration Test Suites',
#  '',
#  'In order to run Docker integration tests, you have to install the `docker` engine on your box.',
#  'The instructions for installation can be found at [the Docker site](https://docs.docker.com/engine/installation/).',
#  'Once installed, the `docker` service needs to be started, if not already running.',
#  'On Linux, this can be done by `sudo service docker start`.',
#  '',
#  '    ./build/mvn install -DskipTests',
#  '    ./build/mvn test -Pdocker-integration-tests -pl :spark-docker-integration-tests_2.11',
#  '',
#  'or',
#  '',
#  '    ./build/sbt docker-integration-tests/test',
#  '---',
#  'layout: global',
#  'title: Cluster Mode Overview',
#  '---',
#  '',
#  'This document gives a short overview of how Spark runs on clusters, to make it easier to understand',
#  'the components involved. Read through the [application submission guide](submitting-applications.html)',
#  'to learn about launching applications on a cluster.',
#  '',
#  '# Components',
#  '',
#  'Spark applications run as independent sets of processes on a cluster, coordinated by the `SparkContext`',
#  'object in your main program (called the _driver program_).',
#  '',
#  'Specifically, to run on a cluster, the SparkContext can connect to several types of _cluster managers_',
#  "(either Spark's own standalone cluster manager, Mesos or YARN), which allocate resources across",
#  'applications. Once connected, Spark acquires *executors* on nodes in the cluster, which are',
#  'processes that run computations and store data for your application.',
#  'Next, it sends your application code (defined by JAR or Python files passed to SparkContext) to',
#  'the executors. Finally, SparkContext sends *tasks* to the executors to run.',
#  '',
#  '<p style="text-align: center;">',
#  '  <img src="img/cluster-overview.png" title="Spark cluster components" alt="Spark cluster components" />',
#  '</p>',
#  '',
#  'There are several useful things to note about this architecture:',
#  '',
#  '1. Each application gets its own executor processes, which stay up for the duration of the whole',
#  '   application and run tasks in multiple threads. This has the benefit of isolating applications',
#  '   from each other, on both the scheduling side (each driver schedules its own tasks) and executor',
#  '   side (tasks from different applications run in different JVMs). However, it also means that',
#  '   data cannot be shared across different Spark applications (instances of SparkContext) without',
#  '   writing it to an external storage system.',
#  '2. Spark is agnostic to the underlying cluster manager. As long as it can acquire executor',
#  '   processes, and these communicate with each other, it is relatively easy to run it even on a',
#  '   cluster manager that also supports other applications (e.g. Mesos/YARN).',
#  '3. The driver program must listen for and accept incoming connections from its executors throughout',
#  '   its lifetime (e.g., see [spark.driver.port in the network config',
#  '   section](configuration.html#networking)). As such, the driver program must be network',
#  '   addressable from the worker nodes.',
#  '4. Because the driver schedules tasks on the cluster, it should be run close to the worker',
#  "   nodes, preferably on the same local area network. If you'd like to send requests to the",
#  "   cluster remotely, it's better to open an RPC to the driver and have it submit operations",
#  '   from nearby than to run a driver far away from the worker nodes.',
#  '',
#  '# Cluster Manager Types',
#  '',
#  'The system currently supports three cluster managers:',
#  '',
#  '* [Standalone](spark-standalone.html) -- a simple cluster manager included with Spark that makes it',
#  '  easy to set up a cluster.',
#  '* [Apache Mesos](running-on-mesos.html) -- a general cluster manager that can also run Hadoop MapReduce',
#  '  and service applications.',
#  '* [Hadoop YARN](running-on-yarn.html) -- the resource manager in Hadoop 2.',
#  '* [Kubernetes (experimental)](https://github.com/apache-spark-on-k8s/spark) -- In addition to the above,',
#  'there is experimental support for Kubernetes. Kubernetes is an open-source platform',
#  'for providing container-centric infrastructure. Kubernetes support is being actively',
#  'developed in an [apache-spark-on-k8s](https://github.com/apache-spark-on-k8s/) Github organization. ',
#  "For documentation, refer to that project's README.",
#  '',
#  '# Submitting Applications',
#  '',
#  'Applications can be submitted to a cluster of any type using the `spark-submit` script.',
#  'The [application submission guide](submitting-applications.html) describes how to do this.',
#  '',
#  '# Monitoring',
#  '',
#  'Each driver program has a web UI, typically on port 4040, that displays information about running',
#  'tasks, executors, and storage usage. Simply go to `http://<driver-node>:4040` in a web browser to',
#  'access this UI. The [monitoring guide](monitoring.html) also describes other monitoring options.',
#  '',
#  '# Job Scheduling',
#  '',
#  'Spark gives control over resource allocation both _across_ applications (at the level of the cluster',
#  'manager) and _within_ applications (if multiple computations are happening on the same SparkContext).',
#  'The [job scheduling overview](job-scheduling.html) describes this in more detail.',
#  '',
#  '# Glossary',
#  '',
#  "The following table summarizes terms you'll see used to refer to cluster concepts:",
#  '',
#  '<table class="table">',
#  '  <thead>',
#  '    <tr><th style="width: 130px;">Term</th><th>Meaning</th></tr>',
#  '  </thead>',
#  '  <tbody>',
#  '    <tr>',
#  '      <td>Application</td>',
#  '      <td>User program built on Spark. Consists of a <em>driver program</em> and <em>executors</em> on the cluster.</td>',
#  '    </tr>',
#  '    <tr>',
#  '      <td>Application jar</td>',
#  '      <td>',
#  "        A jar containing the user's Spark application. In some cases users will want to create",
#  '        an "uber jar" containing their application along with its dependencies. The user\'s jar',
#  '        should never include Hadoop or Spark libraries, however, these will be added at runtime.',
#  '      </td>',
#  '    </tr>',
#  '    <tr>',
#  '      <td>Driver program</td>',
#  '      <td>The process running the main() function of the application and creating the SparkContext</td>',
#  '    </tr>',
#  '    <tr>',
#  '      <td>Cluster manager</td>',
#  '      <td>An external service for acquiring resources on the cluster (e.g. standalone manager, Mesos, YARN)</td>',
#  '    </tr>',
#  '    <tr>',
#  '      <td>Deploy mode</td>',
#  '      <td>Distinguishes where the driver process runs. In "cluster" mode, the framework launches',
#  '        the driver inside of the cluster. In "client" mode, the submitter launches the driver',
#  '        outside of the cluster.</td>',
#  '    </tr>',
#  '    <tr>',
#  '      <td>Worker node</td>',
#  '      <td>Any node that can run application code in the cluster</td>',
#  '    </tr>',
#  '    <tr>',
#  '      <td>Executor</td>',
#  '      <td>A process launched for an application on a worker node, that runs tasks and keeps data in memory',
#  '        or disk storage across them. Each application has its own executors.</td>',
#  '    </tr>',
#  '    <tr>',
#  '      <td>Task</td>',
#  '      <td>A unit of work that will be sent to one executor</td>',
#  '    </tr>',
#  '    <tr>',
#  '      <td>Job</td>',
#  '      <td>A parallel computation consisting of multiple tasks that gets spawned in response to a Spark action',
#  "        (e.g. <code>save</code>, <code>collect</code>); you'll see this term used in the driver's logs.</td>",
#  '    </tr>',
#  '    <tr>',
#  '      <td>Stage</td>',
#  '      <td>Each job gets divided into smaller sets of tasks called <em>stages</em> that depend on each other',
#  "        (similar to the map and reduce stages in MapReduce); you'll see this term used in the driver's logs.</td>",
#  '    </tr>',
#  '  </tbody>',
#  '</table>',
#  '---',
#  'layout: global',
#  'displayTitle: Spark Configuration',
#  'title: Configuration',
#  '---',
#  '* This will become a table of contents (this text will be scraped).',
#  '{:toc}',
#  '',
#  'Spark provides three locations to configure the system:',
#  '',
#  '* [Spark properties](#spark-properties) control most application parameters and can be set by using',
#  '  a [SparkConf](api/scala/index.html#org.apache.spark.SparkConf) object, or through Java',
#  '  system properties.',
#  '* [Environment variables](#environment-variables) can be used to set per-machine settings, such as',
#  '  the IP address, through the `conf/spark-env.sh` script on each node.',
#  '* [Logging](#configuring-logging) can be configured through `log4j.properties`.',
#  '',
#  '# Spark Properties',
#  '',
#  'Spark properties control most application settings and are configured separately for each',
#  'application. These properties can be set directly on a',
#  '[SparkConf](api/scala/index.html#org.apache.spark.SparkConf) passed to your',
#  '`SparkContext`. `SparkConf` allows you to configure some of the common properties',
#  '(e.g. master URL and application name), as well as arbitrary key-value pairs through the',
#  '`set()` method. For example, we could initialize an application with two threads as follows:',
#  '',
#  'Note that we run with local[2], meaning two threads - which represents "minimal" parallelism,',
#  'which can help detect bugs that only exist when we run in a distributed context.',
#  '',
#  '{% highlight scala %}',
#  'val conf = new SparkConf()',
#  '             .setMaster("local[2]")',
#  '             .setAppName("CountingSheep")',
#  'val sc = new SparkContext(conf)',
#  '{% endhighlight %}',
#  '',
#  'Note that we can have more than 1 thread in local mode, and in cases like Spark Streaming, we may',
#  'actually require more than 1 thread to prevent any sort of starvation issues.',
#  '',
#  'Properties that specify some time duration should be configured with a unit of time.',
#  'The following format is accepted:',
#  '',
#  '    25ms (milliseconds)',
#  '    5s (seconds)',
#  '    10m or 10min (minutes)',
#  '    3h (hours)',
#  '    5d (days)',
#  '    1y (years)',
#  '',
#  '',
#  'Properties that specify a byte size should be configured with a unit of size.',
#  'The following format is accepted:',
#  '',
#  '    1b (bytes)',
#  '    1k or 1kb (kibibytes = 1024 bytes)',
#  '    1m or 1mb (mebibytes = 1024 kibibytes)',
#  '    1g or 1gb (gibibytes = 1024 mebibytes)',
#  '    1t or 1tb (tebibytes = 1024 gibibytes)',
#  '    1p or 1pb (pebibytes = 1024 tebibytes)',
#  '',
#  '## Dynamically Loading Spark Properties',
#  '',
#  'In some cases, you may want to avoid hard-coding certain configurations in a `SparkConf`. For',
#  "instance, if you'd like to run the same application with different masters or different",
#  'amounts of memory. Spark allows you to simply create an empty conf:',
#  '',
#  '{% highlight scala %}',
#  'val sc = new SparkContext(new SparkConf())',
#  '{% endhighlight %}',
#  '',
#  'Then, you can supply configuration values at runtime:',
#  '{% highlight bash %}',
#  './bin/spark-submit --name "My app" --master local[4] --conf spark.eventLog.enabled=false',
#  '  --conf "spark.executor.extraJavaOptions=-XX:+PrintGCDetails -XX:+PrintGCTimeStamps" myApp.jar',
#  '{% endhighlight %}',
#  '',
#  'The Spark shell and [`spark-submit`](submitting-applications.html)',
#  'tool support two ways to load configurations dynamically. The first are command line options,',
#  'such as `--master`, as shown above. `spark-submit` can accept any Spark property using the `--conf`',
#  'flag, but uses special flags for properties that play a part in launching the Spark application.',
#  'Running `./bin/spark-submit --help` will show the entire list of these options.',
#  '',
#  '`bin/spark-submit` will also read configuration options from `conf/spark-defaults.conf`, in which',
#  'each line consists of a key and a value separated by whitespace. For example:',
#  '',
#  '    spark.master            spark://5.6.7.8:7077',
#  '    spark.executor.memory   4g',
#  '    spark.eventLog.enabled  true',
#  '    spark.serializer        org.apache.spark.serializer.KryoSerializer',
#  '',
#  'Any values specified as flags or in the properties file will be passed on to the application',
#  'and merged with those specified through SparkConf. Properties set directly on the SparkConf',
#  'take highest precedence, then flags passed to `spark-submit` or `spark-shell`, then options',
#  'in the `spark-defaults.conf` file. A few configuration keys have been renamed since earlier',
#  'versions of Spark; in such cases, the older key names are still accepted, but take lower',
#  'precedence than any instance of the newer key.',
#  '',
#  '## Viewing Spark Properties',
#  '',
#  'The application web UI at `http://<driver>:4040` lists Spark properties in the "Environment" tab.',
#  'This is a useful place to check to make sure that your properties have been set correctly. Note',
#  'that only values explicitly specified through `spark-defaults.conf`, `SparkConf`, or the command',
#  'line will appear. For all other configuration properties, you can assume the default value is used.',
#  '',
#  '## Available Properties',
#  '',
#  'Most of the properties that control internal settings have reasonable default values. Some',
#  'of the most common options to set are:',
#  '',
#  '### Application Properties',
#  '',
#  '<table class="table">',
#  '<tr><th>Property Name</th><th>Default</th><th>Meaning</th></tr>',
#  '<tr>',
#  '  <td><code>spark.app.name</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    The name of your application. This will appear in the UI and in log data.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.driver.cores</code></td>',
#  '  <td>1</td>',
#  '  <td>',
#  '    Number of cores to use for the driver process, only in cluster mode.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.driver.maxResultSize</code></td>',
#  '  <td>1g</td>',
#  '  <td>',
#  '    Limit of total size of serialized results of all partitions for each Spark action (e.g. collect).',
#  '    Should be at least 1M, or 0 for unlimited. Jobs will be aborted if the total size',
#  '    is above this limit.',
#  '    Having a high limit may cause out-of-memory errors in driver (depends on spark.driver.memory',
#  '    and memory overhead of objects in JVM). Setting a proper limit can protect the driver from',
#  '    out-of-memory errors.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.driver.memory</code></td>',
#  '  <td>1g</td>',
#  '  <td>',
#  '    Amount of memory to use for the driver process, i.e. where SparkContext is initialized.',
#  '    (e.g. <code>1g</code>, <code>2g</code>).',
#  '',
#  '    <br /><em>Note:</em> In client mode, this config must not be set through the <code>SparkConf</code>',
#  '    directly in your application, because the driver JVM has already started at that point.',
#  '    Instead, please set this through the <code>--driver-memory</code> command line option',
#  '    or in your default properties file.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.memory</code></td>',
#  '  <td>1g</td>',
#  '  <td>',
#  '    Amount of memory to use per executor process (e.g. <code>2g</code>, <code>8g</code>).',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.extraListeners</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    A comma-separated list of classes that implement <code>SparkListener</code>; when initializing',
#  "    SparkContext, instances of these classes will be created and registered with Spark's listener",
#  '    bus.  If a class has a single-argument constructor that accepts a SparkConf, that constructor',
#  '    will be called; otherwise, a zero-argument constructor will be called. If no valid constructor',
#  '    can be found, the SparkContext creation will fail with an exception.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.local.dir</code></td>',
#  '  <td>/tmp</td>',
#  '  <td>',
#  '    Directory to use for "scratch" space in Spark, including map output files and RDDs that get',
#  '    stored on disk. This should be on a fast, local disk in your system. It can also be a',
#  '    comma-separated list of multiple directories on different disks.',
#  '',
#  '    NOTE: In Spark 1.0 and later this will be overridden by SPARK_LOCAL_DIRS (Standalone, Mesos) or',
#  '    LOCAL_DIRS (YARN) environment variables set by the cluster manager.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.logConf</code></td>',
#  '  <td>false</td>',
#  '  <td>',
#  '    Logs the effective SparkConf as INFO when a SparkContext is started.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.master</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    The cluster manager to connect to. See the list of',
#  '    <a href="submitting-applications.html#master-urls"> allowed master URL\'s</a>.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.submit.deployMode</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    The deploy mode of Spark driver program, either "client" or "cluster",',
#  '    Which means to launch driver program locally ("client")',
#  '    or remotely ("cluster") on one of the nodes inside the cluster.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.log.callerContext</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    Application information that will be written into Yarn RM log/HDFS audit log when running on Yarn/HDFS.',
#  '    Its length depends on the Hadoop configuration <code>hadoop.caller.context.max.size</code>. It should be concise,',
#  '    and typically can have up to 50 characters.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.driver.supervise</code></td>',
#  '  <td>false</td>',
#  '  <td>',
#  '    If true, restarts the driver automatically if it fails with a non-zero exit status.',
#  '    Only has effect in Spark standalone mode or Mesos cluster deploy mode.',
#  '  </td>',
#  '</tr>',
#  '</table>',
#  '',
#  'Apart from these, the following properties are also available, and may be useful in some situations:',
#  '',
#  '### Runtime Environment',
#  '',
#  '<table class="table">',
#  '<tr><th>Property Name</th><th>Default</th><th>Meaning</th></tr>',
#  '<tr>',
#  '  <td><code>spark.driver.extraClassPath</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    Extra classpath entries to prepend to the classpath of the driver.',
#  '',
#  '    <br /><em>Note:</em> In client mode, this config must not be set through the <code>SparkConf</code>',
#  '    directly in your application, because the driver JVM has already started at that point.',
#  '    Instead, please set this through the <code>--driver-class-path</code> command line option or in',
#  '    your default properties file.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.driver.extraJavaOptions</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    A string of extra JVM options to pass to the driver. For instance, GC settings or other logging.',
#  '    Note that it is illegal to set maximum heap size (-Xmx) settings with this option. Maximum heap',
#  '    size settings can be set with <code>spark.driver.memory</code> in the cluster mode and through',
#  '    the <code>--driver-memory</code> command line option in the client mode.',
#  '',
#  '    <br /><em>Note:</em> In client mode, this config must not be set through the <code>SparkConf</code>',
#  '    directly in your application, because the driver JVM has already started at that point.',
#  '    Instead, please set this through the <code>--driver-java-options</code> command line option or in',
#  '    your default properties file.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.driver.extraLibraryPath</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    Set a special library path to use when launching the driver JVM.',
#  '',
#  '    <br /><em>Note:</em> In client mode, this config must not be set through the <code>SparkConf</code>',
#  '    directly in your application, because the driver JVM has already started at that point.',
#  '    Instead, please set this through the <code>--driver-library-path</code> command line option or in',
#  '    your default properties file.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.driver.userClassPathFirst</code></td>',
#  '  <td>false</td>',
#  '  <td>',
#  "    (Experimental) Whether to give user-added jars precedence over Spark's own jars when loading",
#  "    classes in the driver. This feature can be used to mitigate conflicts between Spark's",
#  '    dependencies and user dependencies. It is currently an experimental feature.',
#  '',
#  '    This is used in cluster mode only.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.extraClassPath</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    Extra classpath entries to prepend to the classpath of executors. This exists primarily for',
#  '    backwards-compatibility with older versions of Spark. Users typically should not need to set',
#  '    this option.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.extraJavaOptions</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    A string of extra JVM options to pass to executors. For instance, GC settings or other logging.',
#  '    Note that it is illegal to set Spark properties or maximum heap size (-Xmx) settings with this',
#  '    option. Spark properties should be set using a SparkConf object or the spark-defaults.conf file',
#  '    used with the spark-submit script. Maximum heap size settings can be set with spark.executor.memory.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.extraLibraryPath</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  "    Set a special library path to use when launching executor JVM's.",
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.logs.rolling.maxRetainedFiles</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    Sets the number of latest rolling log files that are going to be retained by the system.',
#  '    Older log files will be deleted. Disabled by default.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.logs.rolling.enableCompression</code></td>',
#  '  <td>false</td>',
#  '  <td>',
#  '    Enable executor log compression. If it is enabled, the rolled executor logs will be compressed.',
#  '    Disabled by default.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.logs.rolling.maxSize</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    Set the max size of the file in bytes by which the executor logs will be rolled over.',
#  '    Rolling is disabled by default. See <code>spark.executor.logs.rolling.maxRetainedFiles</code>',
#  '    for automatic cleaning of old logs.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.logs.rolling.strategy</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    Set the strategy of rolling of executor logs. By default it is disabled. It can',
#  '    be set to "time" (time-based rolling) or "size" (size-based rolling). For "time",',
#  '    use <code>spark.executor.logs.rolling.time.interval</code> to set the rolling interval.',
#  '    For "size", use <code>spark.executor.logs.rolling.maxSize</code> to set',
#  '    the maximum file size for rolling.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.logs.rolling.time.interval</code></td>',
#  '  <td>daily</td>',
#  '  <td>',
#  '    Set the time interval by which the executor logs will be rolled over.',
#  '    Rolling is disabled by default. Valid values are <code>daily</code>, <code>hourly</code>, <code>minutely</code> or',
#  '    any interval in seconds. See <code>spark.executor.logs.rolling.maxRetainedFiles</code>',
#  '    for automatic cleaning of old logs.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executor.userClassPathFirst</code></td>',
#  '  <td>false</td>',
#  '  <td>',
#  '    (Experimental) Same functionality as <code>spark.driver.userClassPathFirst</code>, but',
#  '    applied to executor instances.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.executorEnv.[EnvironmentVariableName]</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    Add the environment variable specified by <code>EnvironmentVariableName</code> to the Executor',
#  '    process. The user can specify multiple of these to set multiple environment variables.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.redaction.regex</code></td>',
#  '  <td>(?i)secret|password</td>',
#  '  <td>',
#  '    Regex to decide which Spark configuration properties and environment variables in driver and',
#  '    executor environments contain sensitive information. When this regex matches a property key or',
#  '    value, the value is redacted from the environment UI and various logs like YARN and event logs.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.python.profile</code></td>',
#  '  <td>false</td>',
#  '  <td>',
#  '    Enable profiling in Python worker, the profile result will show up by <code>sc.show_profiles()</code>,',
#  '    or it will be displayed before the driver exiting. It also can be dumped into disk by',
#  '    <code>sc.dump_profiles(path)</code>. If some of the profile results had been displayed manually,',
#  '    they will not be displayed automatically before driver exiting.',
#  '',
#  '    By default the <code>pyspark.profiler.BasicProfiler</code> will be used, but this can be overridden by',
#  '    passing a profiler class in as a parameter to the <code>SparkContext</code> constructor.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.python.profile.dump</code></td>',
#  '  <td>(none)</td>',
#  '  <td>',
#  '    The directory which is used to dump the profile result before driver exiting.',
#  '    The results will be dumped as separated file for each RDD. They can be loaded',
#  '    by ptats.Stats(). If this is specified, the profile result will not be displayed',
#  '    automatically.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.python.worker.memory</code></td>',
#  '  <td>512m</td>',
#  '  <td>',
#  '    Amount of memory to use per python worker process during aggregation, in the same',
#  '    format as JVM memory strings (e.g. <code>512m</code>, <code>2g</code>). If the memory',
#  '    used during aggregation goes above this amount, it will spill the data into disks.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.python.worker.reuse</code></td>',
#  '  <td>true</td>',
#  '  <td>',
#  '    Reuse Python worker or not. If yes, it will use a fixed number of Python workers,',
#  '    does not need to fork() a Python process for every tasks. It will be very useful',
#  '    if there is large broadcast, then the broadcast will not be needed to transferred',
#  '    from JVM to Python worker for every task.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.files</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Comma-separated list of files to be placed in the working directory of each executor.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.submit.pyFiles</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Comma-separated list of .zip, .egg, or .py files to place on the PYTHONPATH for Python apps.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.jars</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Comma-separated list of local jars to include on the driver and executor classpaths.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.jars.packages</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Comma-separated list of Maven coordinates of jars to include on the driver and executor',
#  '    classpaths. The coordinates should be groupId:artifactId:version. If <code>spark.jars.ivySettings</code>',
#  '    is given artifacts will be resolved according to the configuration in the file, otherwise artifacts',
#  '    will be searched for in the local maven repo, then maven central and finally any additional remote',
#  '    repositories given by the command-line option <code>--repositories</code>. For more details, see',
#  '    <a href="submitting-applications.html#advanced-dependency-management">Advanced Dependency Management</a>.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.jars.excludes</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Comma-separated list of groupId:artifactId, to exclude while resolving the dependencies',
#  '    provided in <code>spark.jars.packages</code> to avoid dependency conflicts.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.jars.ivy</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Path to specify the Ivy user directory, used for the local Ivy cache and package files from',
#  '    <code>spark.jars.packages</code>. This will override the Ivy property <code>ivy.default.ivy.user.dir</code>',
#  '    which defaults to ~/.ivy2.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.jars.ivySettings</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Path to an Ivy settings file to customize resolution of jars specified using <code>spark.jars.packages</code>',
#  '    instead of the built-in defaults, such as maven central. Additional repositories given by the command-line',
#  '    option <code>--repositories</code> will also be included. Useful for allowing Spark to resolve artifacts from behind',
#  '    a firewall e.g. via an in-house artifact server like Artifactory. Details on the settings file format can be',
#  '    found at http://ant.apache.org/ivy/history/latest-milestone/settings.html',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.pyspark.driver.python</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Python binary executable to use for PySpark in driver.',
#  '    (default is <code>spark.pyspark.python</code>)',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.pyspark.python</code></td>',
#  '  <td></td>',
#  '  <td>',
#  '    Python binary executable to use for PySpark in both driver and executors.',
#  '  </td>',
#  '</tr>',
#  '</table>',
#  '',
#  '### Shuffle Behavior',
#  '',
#  '<table class="table">',
#  '<tr><th>Property Name</th><th>Default</th><th>Meaning</th></tr>',
#  '<tr>',
#  '  <td><code>spark.reducer.maxSizeInFlight</code></td>',
#  '  <td>48m</td>',
#  '  <td>',
#  '    Maximum size of map outputs to fetch simultaneously from each reduce task. Since',
#  '    each output requires us to create a buffer to receive it, this represents a fixed memory',
#  '    overhead per reduce task, so keep it small unless you have a large amount of memory.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.reducer.maxReqsInFlight</code></td>',
#  '  <td>Int.MaxValue</td>',
#  '  <td>',
#  '    This configuration limits the number of remote requests to fetch blocks at any given point.',
#  '    When the number of hosts in the cluster increase, it might lead to very large number',
#  '    of in-bound connections to one or more nodes, causing the workers to fail under load.',
#  '    By allowing it to limit the number of fetch requests, this scenario can be mitigated.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.compress</code></td>',
#  '  <td>true</td>',
#  '  <td>',
#  '    Whether to compress map output files. Generally a good idea. Compression will use',
#  '    <code>spark.io.compression.codec</code>.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.file.buffer</code></td>',
#  '  <td>32k</td>',
#  '  <td>',
#  '    Size of the in-memory buffer for each shuffle file output stream. These buffers',
#  '    reduce the number of disk seeks and system calls made in creating intermediate shuffle files.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.io.maxRetries</code></td>',
#  '  <td>3</td>',
#  '  <td>',
#  '    (Netty only) Fetches that fail due to IO-related exceptions are automatically retried if this is',
#  '    set to a non-zero value. This retry logic helps stabilize large shuffles in the face of long GC',
#  '    pauses or transient network connectivity issues.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.io.numConnectionsPerPeer</code></td>',
#  '  <td>1</td>',
#  '  <td>',
#  '    (Netty only) Connections between hosts are reused in order to reduce connection buildup for',
#  '    large clusters. For clusters with many hard disks and few hosts, this may result in insufficient',
#  '    concurrency to saturate all disks, and so users may consider increasing this value.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.io.preferDirectBufs</code></td>',
#  '  <td>true</td>',
#  '  <td>',
#  '    (Netty only) Off-heap buffers are used to reduce garbage collection during shuffle and cache',
#  '    block transfer. For environments where off-heap memory is tightly limited, users may wish to',
#  '    turn this off to force all allocations from Netty to be on-heap.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.io.retryWait</code></td>',
#  '  <td>5s</td>',
#  '  <td>',
#  '    (Netty only) How long to wait between retries of fetches. The maximum delay caused by retrying',
#  '    is 15 seconds by default, calculated as <code>maxRetries * retryWait</code>.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.service.enabled</code></td>',
#  '  <td>false</td>',
#  '  <td>',
#  '    Enables the external shuffle service. This service preserves the shuffle files written by',
#  '    executors so the executors can be safely removed. This must be enabled if',
#  '    <code>spark.dynamicAllocation.enabled</code> is "true". The external shuffle service',
#  '    must be set up in order to enable it. See',
#  '    <a href="job-scheduling.html#configuration-and-setup">dynamic allocation',
#  '    configuration and setup documentation</a> for more information.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.service.port</code></td>',
#  '  <td>7337</td>',
#  '  <td>',
#  '    Port on which the external shuffle service will run.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.service.index.cache.entries</code></td>',
#  '  <td>1024</td>',
#  '  <td>',
#  '    Max number of entries to keep in the index cache of the shuffle service.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.sort.bypassMergeThreshold</code></td>',
#  '  <td>200</td>',
#  '  <td>',
#  '    (Advanced) In the sort-based shuffle manager, avoid merge-sorting data if there is no',
#  '    map-side aggregation and there are at most this many reduce partitions.',
#  '  </td>',
#  '</tr>',
#  '<tr>',
#  '  <td><code>spark.shuffle.spill.compress</code></td>',
#  '  <td>true</td>',
#  '  <td>',
#  ...]

# %%
#from pyspark import SparkContext
#sc = SparkContext(appName = "check")
textfile = sc.textFile('C:/Users/carlyna.bondiombouy/Desktop/tmp/spark-docs/*.csv')
textfile.collect()
# Out:
# [',,LIST OF PETITIONS/LETTERS IN CITIZENS RIGHT CENTRE (CRC) 2013,',
#  'File No.,Name of Petition/Complaint/Request,Subject matter of Petition,Action Taken',
#  'CRC/3/2012,Activist Prince Obina Njoku of Legal Pursuit And for Human Rights Dept.,Complaint of one Isaiah Ogbugbo against Nosa Osifo over Landlord and Tenant matter,Concluded',
#  'CRC/06/2012,Mrs. Ohiokha Joy & 3ors,Injustice in Edo State Youth Employment Scheme (Edo Yes),On going',
#  'CRC/25/2012,Mr. Amos Ogiemudia Arase,Arase wrongly terminated in 1986,On going',
#  'CRC/45/2012,Christ Chambers,Towed/seized Dodge Ram Motor vehicle of Barrister Isaac Ozua by officers of Ministry of Transport,On going',
#  'CRC/10/20/2012,Kingsley Momodu Ijebor,Wrongful deprivation of my benefits under the Will of late Mr. Momodu Ijebor by Mr. George Momodu Ijebor,On going',
#  'CRC/2/2012,Lucky Uhuangho,Complaint of an illegitimate taking over of my inheritance,Concluded',
#  'CRC/10/90/T1,Staff of Austin Laz & Co. Ltd,Non-payment of salaries,On going',
#  'CRC/10/9/2013,Mr. Chime Chinedu Enoch,Proposed N.G.O. called Peer Education and Empowerment Initiative,On going',
#  'CGA/934/T1,,Payment of Entitlement, Still on going',
#  ',Anthony Obende,Anthony Obende for petition against the Bank of Agric. For Justice Petition against the Bank of Agric for their malicious damage to my apartment & personal properties,On going',
#  'CRC/17/2013,,Absorption of twelve paid teachers in Edo State College into the State teaching service,On going',
#  'CRC/2/10/2013,,Gross abuse of my rights and that of my children unlawfully,Concluded',
#  'CRC/13/6/2013,,Where else do I go for Justice,On going',
#  'CRC/24/2013,Philip Equaseki Asonmwonrir,"Letters on the acts of illegalities, disdain and utter disrespect for family privacy, being perpetrated by Austrian government",On going',
#  'CRC/31/2013,,Gross violation of rights of Citizen Obende .A call for Justice,On going',
#  'CRC/26/6/2013,,Solicitation for human right and justice,On going',
#  'CRC/15/7/2013,Akintola Azagbor,Complaint Against Nigeria Police Force (N.P.F) Auchi,On going',
#  'CRC/10/7/2013,,Letter of Complaint,On going',
#  'CRC/16/7/2013,Saad .B. Muhammed,Letter of Complaint against landlord,On going',
#  'CRC/11/9/2013,,"A case of assault, molestation and conduct likely to cause breach of public peace",On going',
#  'CRC/12/9/2013,Mr. Benjamin Agbonfo,Letters to petition Mr. Kabiru Momoh for forcing him to sign undertaking written by him,On going',
#  'CRC/24/9/2013,Mr. Andrew Otoibhi,Assistance to recover payment of outstanding salary arrearsfrom Edo State Saw Millers Association,On going',
#  ',,,',
#  'S/N,POI,Address,Place,Y-Coordinate,X-Coordinate',
#  '1,OMOKARO JUNCTION ,ALONG SILUKO ROAD,SILUKO ROAD,6.3573,5.600166667',
#  '2,EBO JUNCTION STREET,OBA MARKET ROAD,OBA MARKET  ROAD,6.336016667,5.619183333',
#  '3,POLICE STATION ,BY OBA MART ROAD,OBA MARKET  ROAD,6.335683333,5.620016667',
#  '4,IBIWE STREET,OPPOSITE EBO STREET JUNCTION,IBIWE,6.338416667,5.620116667',
#  '5,EMOTAN COLLEGE,WIRE ROAD,,6.3467,5.619333333',
#  '6,BEHIND ST AUGUSTINE CHURCH,SILUKO ROAD,SILUKO ROAD,6.344066667,5.614066667',
#  '7,IGU QUARTER,,OGBE,6.279333333,5.52935',
#  '8,OMORUYI JUNCTION,ERHUMWUNSE,,6.343916667,5.599133333',
#  '9,UYINSTREET JUNCTION,EGHOSA STREET,,6.344633333,5.598466667',
#  '10,EHENDEN STREET,2ND CEMETRY,,6.34175,5.606733333',
#  '11,INDEPENDENT LANE,EHENEDE STREETT,,6.3402,5.6054',
#  '12,ILLEGAL WASTE DUMP ALONG,,UPPER MISSION EXT,6.377533333,5.6542',
#  '13,ILLEGAL WASTE DUMP BY TEMBOGA JUN,,UPPER MISSION EXT,6.376783333,5.6496',
#  '14,ILLEGAL WASTE DUMP BEFOR IKPOBA RIVER ALONG UPPER MIS EXT,,,6.372866667,5.646583333',
#  '15,ILLEGAL WASTE DUMP BY MOAT B4OWOSENI JUNC ,ALONG MISSION RD,,6.3472,5.630033333',
#  '16,ILLEGAL WASTE DUMP SITE,AKPAKPAVA,AKPAKPAVA,6.34635,5.6382',
#  'NAME ,LOCATION',
#  'Lisbor Hotel,"No. 4, Sokponba Road, B/C."',
#  'Matice Fast Food,"No. 12, Sokponba Road, B/C."',
#  'Vesa Sea Food,"100A, Off Sokponba Road, B/C."',
#  'Debbies Kitchen,"No. 61, Sokponba, Road, B/C."',
#  'Mrs. Owen,"No. 73B, 2nd East Circular Road, B/C"',
#  'Mama Rita Cold Room,"Sokponba by 2nd East Cikrcular Road, B/C."',
#  'Mrs. UY Fried and Cold Room,"Evbarune , Gbefo Street, B/C."',
#  'Eddyibanga Int. Ltd,',
#  'Farmers Shopping complex,"No. 78, Sokponba Road, B/C"',
#  'The Phimas Garden Hotel,"No. 3, Obazuina Street, Off 1st East Circular Road, Benin City."',
#  'Usama Ivory Hotel,"No. 169, 1st East Circular Road, B/C."',
#  'Two Sisters  Cold Room,"No. 105, Sokponba Road, B/C."',
#  'Mama Enoghayin Cold Room,"No. 105, Sokponba Road, B/C."',
#  'Clement Uyiekpen Cold Room,"No. 73B, 2nd East Circular Road, B/C"',
#  'Rito Cold Room,"No. 105, Sokponba Road, B/C."',
#  'Efifa Cold Room,"No. 105, Sokponba Road, B/C."',
#  'Christy Guest House,"No. 106, Sokponba Road, B/C"',
#  'Sunday M. Meat Shop,"No. 11, Oba Market Road, B/C."',
#  'G.T.I Meat Shop,"No. 25 & 26, Oba Market Road, B/C."',
#  'Judgement MeAT Shop,"No. 11, Oba Market Road, B/C."',
#  'Mrs. Ewalefo,"No. 5, Oba M arket Roiad, B/C."',
#  'Omeka Meat Shop,"No. 24, Oba Market Road, B/C."',
#  'Uzee Meat Shop,"No. 24, Oba Market Road, B/C."',
#  'Meat Shop,"No. 3, Oba Market Road, B/C."',
#  'Mrs. V. Meat Shop,"No. 105, Oba Market Road, B/C."',
#  'Meat Shop,"No. 9, Oba Market Road, B/C."',
#  'I. V. Frozen Food,"No. 18, Oba Market Road, B/C."',
#  'Mrs Rita Odiowe,"No. 11, Oba Market Road, B/C."',
#  'Godfrey Meat,"No. 24, Oba Market Road, B/C."',
#  'Mr. Edogun,"No. 10, Old Oguanogbe Street, B/C."',
#  'Sunny Gas Meat,"No. 24, Oba Market Road, B/C."',
#  'Mrs. Ozede Meat Shop,"No. 12, Ekp;enede Street, B/C."',
#  'Mrs Ebbuzugbe Ice-Cream Shop,"No. 10 Old Uguanogbe Street, B/C."',
#  'C. O. Meat Shop,"No. 22, O ba Market Road, B/C. "',
#  'Mrs. Omorodion,"No. 22, O ba Market Road, B/C. "',
#  'B. B. Meat Shop,"No. 5, Oba M arket Roiad, B/C."',
#  'Destiny Meat Shop,"No. 24, Oba Market Road, B/C."',
#  'Sunday Meat Shoip,"No. 11, Oba Market Road, B/C."',
#  'Mrs Omoregie Meat Shop,"No. 18C, Oba Market Road, B/C."',
#  'F. O. Meat Shop,"No. 18C, Oba Market Road, B/C."',
#  'Pat O. Meat Shop,"Oba Market Road, B/C."',
#  'Mrs Adeban jo Meat Shop,"No. 22, O ba Market Road, B/C. "',
#  'Mr. Tofa Meat Shop,"No. 24, Oba Market Road, B/C."',
#  'Joseph Meat Shop,"No. 22, O ba Market Road, B/C. "',
#  'OTF NI Meat,"No. 24, Oba Market Road, B/C."',
#  'Blessed Boy Meat Shop,"No. 26, Oba Market Road, B/C."',
#  'Christy Meat Shop,"No. 7, Oba Mnarket Road, B/C."',
#  'Ororo Cold Room,"Ogbe Quarters, Benin City"',
#  'Fan Milk Product,"No. 41, Ekenwan Road, B/C."',
#  'Mrs Enabbulele,"No. 14, Plymouth Road, B/C."',
#  'Mrs Enabbulele,"No. 18, Plymouth Road, B/C."',
#  'G.T. Fast Food,"No. 60, Ekenwan Road, B/C."',
#  'Mr. Biggs Fast Food,"No. 107, Ekenwan Road, B/C."',
#  'Matice,"No. 99, Ekenwan Road, B/C."',
#  'Kicken Republic,"No. 100, Ekenwan Road, B/C."',
#  'Frozen Food,Ogbe Quarters',
#  'Rima Bakery,"No. 45, Ogiemudia Street, Ovboutubu Qtrs. B/C."',
#  'Onious Fl avour Hotel,"No. 282, Upper Ekenwan Road, B/C."',
#  'Eddes Restaurant,"No. 2, Ekenwan Road, B/C."',
#  'Bensuhi Guest House,"Ekenwan Road, Benin City."',
#  'Madam Osagiede Restaurant,"No. 33, Oba Market Road, B/C."',
#  'Donhen Frozen Food,"No. 30, Aba Market Rolad, B/C."',
#  'Food Outlet,"By Emotan Hotel, C.I.D. Road, B/C."',
#  'Mr. Biggs Fast Food,"No. 65, Sapele Road, B/C."',
#  'Isoken Bar,"No. 55, Sapele Road, B/C."',
#  'Restaurant & Bar,"Ekae/Evbouriaria Area, Sapele Road, B/C."',
#  'Madam B. Restaurant,"No. 1, Isekhure Way, Sapele Road, B/C."',
#  'Shaden Bakery,"No. 4, Owegie Street, Off Ekenwan Rfoad, B/C."',
#  'K.F.C Plaza,"Ekenwan Road, Benin City."',
#  'Pounded Yam Restaurant,"No. 100, Ekenwan Road, B/C."',
#  'Mr. Frank Hotel,"No. 401, Upper Ekenwan Road, B/C."',
#  'Bright Kitchen,',
#  'Embo Restaurant/Bar,"No. 26, Airport Road, B/C."',
#  'Taste & Class Restaurant and Bar,"No. 36, Airport Road, B/C."',
#  'Pepper Rice,"Chief Osama Shopping Complex, B/C."',
#  'Amala Satisfying Meal,"Chief Osama Shopping Complex, B/C."',
#  'Chin Chin Restaurant,"No. 26, Ezoti Street, B/C."',
#  ' Food Outlet,"No. 6, Airport Road, B/C."',
#  'Zion Pepper Rice,"Chief Osama Shopping Complex, B/C."',
#  'Mama Put,"Ibewe Street, B/C."',
#  'Eddy Meat Shop,"61, Yoruba Str. Benin City"',
#  'Food Outlet,"No. 39, Boundary Road, B/C."',
#  'Ukunuyi Store,"No. 1, Off Boundary Road, G.R.A., B/C."',
#  'The Right Choice,"No. 43, Ihama Street, B/C."',
#  'Car Wash,"No. 21, Adesuwa Road, Off Sapele Road, B/C."',
#  'Bright Restaurant & Bar,"No. k2, Adesuwa Road, Off Sapele Road, B/C."',
#  'Kem Crescent & Bar,"No. 37, Ihama Street, G.R.A., B/C."',
#  'Madam Ihama,"No. 46, Ihama Street, G.R.A., B/C."',
#  'Theresa Restaurant & Bar,',
#  'U.K. Bread ,"No. 38, L agos Street, B/C."',
#  'Food Outlet,"No. 208, Upper Sokponba Road, B/C."',
#  'Randehi Royal Hotel,"No. 6, off Ihama Street, B/C."',
#  'Amala Sport,"Ebeneza Junction, G.R.A., B/C."',
#  'The Dinner Food Outlet,"Utop Filling Station, Airport Road, B/C."',
#  'Vics Fast Food,"No. 36, Ihama Street, B/C."',
#  'Odia Sea Fish Food," No. 35, Airport Road, B/C."',
#  'Shape Quest House/Bar,"No. 82, Akenzua Street, B/C."',
#  'Food Outlet,"No. 3. Igun Street, B/C."',
#  'Ogo Food Outlet,"No. 10, Sokponba Road, B/C."',
#  'Act Restaurant antd Bar,"Nlo. 20, Ogongosun Street, B/C."',
#  'Modest Kitchen,"No. 25, Dumez Road, B/C."',
#  '"Amala Spot, Restaurant & Bar","No. 4, Ogbelaka Street, B/C."',
#  'Tonmard Food Outlet,"No. 31, Dumez Road, B/C."',
#  'Food Outlet,"No. 4, Sakponba Road, B/C."',
#  'Nosakhare Bakery,"No. 1, Nosakhare Street, Upper Mission Road, B/C."',
#  'De Peak Restaurant,"No. 16, Dawnson Road, B/C."',
#  'Mafretis Food,"Aram Plaza, New Lagos Road, B/C."',
#  'Unibake Bread,"No. 9, 2nd Victory Street, New Benin, B/C."',
#  'Madam Stainless Restaurant & Bar,"No. 37, Constain Road, New Benin, B/C."',
#  'Citizen Hotel,"No. 40B, Uwa Street, Off Sapele Road, B/C."',
#  'Victory Hotel,"Victory road, Off New Lagos Road, New Benin, B/C."',
#  'State CLO Food Outlet,Benin-City.',
#  'Food is Ready Restaurant & Bar,"63, sapele Road, Benin City"',
#  'Kada Plaza,"35, Sapele road, Benin City"',
#  'western Hotel,"22A, M M Way, Benin City"',
#  'Apex kitchen,"Km 12, Sapele Road,  Benin City"',
#  'Stallion Sea Food,"Sapele Road, Benin City"',
#  'Food Outlet,"56, Sapele Road,  Benin City"',
#  'Restaurant & Bar,"63, sapele Road, Benin City"',
#  'Eddna Water,"18, Ikpokpan Road, Benin City"',
#  'Nkechi Food Outlet,"20, Upper sakponba Road,  Benin City"',
#  'Nwokoyo Eze,"4, Osunde Street, upper Sakponba Road,  Benin City"',
#  'Food Outlet,"124, Upper Sakponba Road,  Benin City"',
#  'Food Outlet,"28, Igbesamwan Street, Benin City"',
#  'Restaurant ,"2, Igbesanmwan Street, Benin City"',
#  'Food Outlet,"24, Upper Sakponba Road, Benin City"',
#  'Spaco Restaurant,"5, Ugbague Street, Benin city"',
#  'Restaurant & Bar,"155, 2nd East Circular Road,  Benin City"',
#  'Restaurant & Bar,"18, Igingan Stree,t Benin City"',
#  'Food Outlet,"36A, 2nd East Circular Road,  Benin City"',
#  'Petty Berist,"42, 2nd East Circular Road, Benin City"',
#  'western Bakery,"10, Ekpenede street, Benin City"',
#  'Shedrach Hulticulture & Agro chemical Ventures,"1, College  Road, Benin City"',
#  'Face to face Restaurant & bar,"242, Upper sakponba Road, Benin City"',
#  'Presidential Hotel,"265, Upper Sakponba Road, Benin City"',
#  'Cold Room ,"Obasogie Street, Benin City"',
#  'Edo / Delta Hotel,"134, Akpakpava Road, Benin City"',
#  'Cold Room ,"87, Second East Circular Road, Benin City"',
#  'Winsa Frozen Food,"93, 2nd East Circular Road, Benin City"',
#  'Meat Shop,"91, 2nd East Circular Road, Benin City"',
#  'Iyamu Cold Room,"3, Ekiosa Street, Benin City"',
#  'Osato meat Shop,"91, 2nd East Circular Road, Benin City"',
#  'Restaurant & Bar,"97, 2nd East Circular Road, Benin City"',
#  'Cold Room ,"96, 2nd East Circular Road, Benin City"',
#  'Cold Room ,"77, 2nd East Circular Road, Benin City"',
#  'Meat Shop,"2nd East Circular Road,  Benin City"',
#  'Cold Room ,"85, 2nd East Circular Road, Benin City"',
#  'Table water,"Igbinedion Street, Benin City"',
#  'Food Outlet,"39, Boundary Road, Benin City"',
#  'Ukumuyi Stores,"1, off Boundary  Road, Benin City"',
#  'Kish Bar,"46, Ihama Road,  Benin City"',
#  'Eddy Meat Shop,"61, Yoruba Str. Benin City"',
#  'Restaurant,"22,  Igbesamwan  Road,  Benin City"',
#  'Cold Room ,"17B, Orobato street, Benin City"',
#  'Cold Room ,"91, 2nd East Circular Road,  Benin City"',
#  'Space Restaurant,"5, Ugbague Street, Benin city"',
#  'Cold Room ,"Evbarunegbefo Street, Ekiosa, Benin City"',
#  'Our Choice water,"Ehaekpen, off Akpakpava street, Benin City"',
#  'Restaurant & Bar,"9, Owoseni Street, Benin City"',
#  'Cold Room ,"9, Efehi Street, Off New lagos  Road, Benin City"',
#  'Bins Hotel,"200A, Ekenwan  Road, Benin City"',
#  'Mr Biggs,"1, Ihama  Road,  Benin City"',
#  'Talk of the Town,"Ede Shopping Complex, Benin City"',
#  'DA Civic Centre,"By Ben Oni Junction, Benin City"',
#  'Supreme Guest House,"28, ben-Oni Road, Benin City"',
#  'Constantial Hotel,"Airport Road,  Benin City"',
#  'Fredric A Hotel,"1, Fred close off gapiona Road, Benin City"',
#  'Fedgard,"JBS Estate, off Boundary Road, Benin City"',
#  'Ritz chartlton Hotel,"64, Boundary Road,  Benin City"',
#  'Motel Benin Plaza,"GRA, Benin City"',
#  'Court Yard Hotel ,"1, Boundary Road, Benin City"',
#  'Bibi Hotel,"72B, Boundary Road, Benin City"',
#  'Bar,"10, 2nd East Circular  Road, Benin City"',
#  'Osakpolor Seas Food,"85, Oliha Palace, Benin City"',
#  'Obazee Cold Room,"Oliha Palace, Benin City"',
#  'Nice Time Restaurant,"8, Uzama street Benin City"',
#  'Devine Cold room,"Oliha Palace, Benin City"',
#  'Restaurant & Bar,"27, T.V Road, Benin City"',
#  'Decency Restaurant & Bar,"Aideyan Avenue, GRA, Benin city"',
#  'Mrs Okafor Restaurant & Bar,"55, New Lagos Road, Benin City"',
#  'Meat Shop,"2nd East Circular Road, Benin City"',
#  'Patient Eze,"63, New lagos  Road,  Benin City"',
#  'Mrs Enabulele,"45, Yoruba street, Benin City"',
#  'Cold Room ,"13B, Owoseni street, Benin City"',
#  'Cold Room ,"13, Owoseni street, Benin City"',
#  'Cold Room ,"63, New lagos  Road,  Benin City"',
#  'Joe Bakery,"18, 1st East Circular Road,  Benin City"',
#  'Mrs Igbinaduwa Cold Room,"Oliha Palace, Benin City"',
#  'Agbel Bar,"61, Ehaekpen Street Benin City"',
#  'Lucky Restaurant,"28, T.V Road, Benin City"',
#  'Kelvison Restaurant & Bar,"178, Siluko Road, Benin City"',
#  'Octagon Restaurant & Bar,"Uwaifo Street, off Siluko Road,  Benin City"',
#  'Insight Bakery,"102c, Siluko Road,  Benin City"',
#  'Eranori Pure Water,"2, Obanosa Street, off Siluko Road, Benin City"',
#  'St Gordon Hotel,"165, Sapele Road, Benin City"',
#  'Twin light Hotel,"32, Wire Road, Benin City"',
#  'Shabel Bakery,"50, T.V Road,  Benin City"',
#  'Restaurant & Bar,"74, Sakpoba Road,  Benin City"',
#  'Mr Good Luck Meat Shop,"15, Oba market Road, Benin City"',
#  'Feb Meat  Shop,"18, Oba market Road,  Benin City"',
#  'The Freedom Meat Shop,"13, Oba Market Road,  Benin City"',
#  'Classic Frozen food,"13, Oba Market Road,  Benin City"',
#  'Judge Meat Shop,"11, Oba market Road,  Benin City"',
#  'D\' Flavour Fast Food,"38, Ekenwan Road,  Benin City"',
#  'Asoteni Hotels,"No. 5A, Ihama Str. Benin City"',
#  'Royal Mable,"Ihama GRA, B/C"',
#  'Zeelodge Bar,"No. 17, Boundry Rd, GRA, Benin City."',
#  'Koso Inter Hotel Guest House,"No. 5, Tonny Annenih Avenue, GRA, BeninCity"',
#  'Farnec Guest House,"No. 4, Tonny Annenih Avenue, GRA, BeninCity"',
#  'Big Joe Hotel,"No. 13, Adesuwa Rd, Benin City."',
#  'C & A Kichen Fast Food,"No. 1, Adesuwa Road, Benin City."',
#  'Patient Ijebu Restaurant & Bar,"No. 84, Sapele Rd, Benin City."',
#  'Mani Igie Food Centre,"No. 165, Sapele Rd, Benin City."',
#  'Chenijav Guest House,"No. 1, Ogiefua Avenue, off St. Saviour Rd, Benin City"',
#  'IVB Meat Shop,"No. 6A, IzuinaSt. New Benin, Benin City."',
#  'Madani Helen meat Shop,"No. 51, New Lagos Road, B/C"',
#  'Iyayi brother Cool Room,"No. 94, 2nd East Circular Rd, B/C"',
#  'Meat Cold Room,"No 8, lawani St. New Benin, B/C"',
#  'Mrs. Queen Amadin Cold Room,"No. 1, Upper lawani St. off new Lagos Rd, B/C"',
#  'Mrs. C. Iyayi Cold Room,"No. 11, Udukpayi St. New Benin, B/C"',
#  'Mrs. Bello Cold Room,"No. 3, okundaiye St. off new benin, B/C"',
#  'Mrs. Big Fast Food,"No. 57, Akpakpava St. B/C"',
#  'Twins Food Outlet,"No. 59, 1st East Circular Rd, B/C"',
#  'BB Spits Fast Food,"No. 37, 1st East Circular Rd, B/C"',
#  'Opeyemi Bakery,"No. 9, Noruwa St. Old Western Rd, B/C"',
#  'Restaurant & Bar,"No. 29, New lagos rd, B/C"',
#  'Mrs. Omokaro restaurant & bar,"No. 65, Lawani St. Off new Lagos Rd, B/C"',
#  'Restaurant & Bar,"No. 40, New Lagos Rd, B/C"',
#  'Makacin Restaurant & Bar,"Boundry Rd, GRA. B/C"',
#  'Mr. N. Omorodion Food Outlet,"No. 92, igun Str. B/C"',
#  'Food Outlet,"No. 7, Oka Eben Str. Off James Watt Rd, B/C"',
#  'Food is Ready,"No. 53A, Akpakpava Str. B/C"',
#  'Mrs. Osagie Restaurant & bar,"No. 140, 2nd East Circular Rd, B/C"',
#  'Victoria Obasuyi,"No. 27, Eguadase Str. B/C"',
#  'Restaurant & Bar,"By Iyobosa Junction, 2nd East Circular Rd, B/C"',
#  'Madam T. Amala Sport,"No. 27C, Ehaikpen Str. B/C"',
#  'our Choice Table Water,"No. 20, Ehaikpen Str. B/C"',
#  'Madani Rstaurant Bar,"No. 29, Akpakpava Str. B/C"',
#  'Mama Chinedu Cold Room,"No. 49b, new Lagos Rd, B/C"',
#  'Mr. obazee Cold Room,"No. 39, Yoruba Str. Off New Lagos Rd, B/C"',
#  'Mrs. Ehigie Cold Room,"No. 39, Yoruba Str. Off New Lagos Rd, B/C"',
#  'Mrs. Omoruyi Cold Room,"No. 39B, Yoruba Str. Off New Lagos Rd, B/C"',
#  'Mrs. Akhitenor Cold Room,"No. 39B, Yoruba Str. Off New Lagos Rd, B/C"',
#  'Mrs. Onio-Atu Cold Room,"No. 48, Yoruba Str. Off New Lagos Rd, B/C"',
#  'Mrs. Iyamu Cold Room,"No. 6, 1st ofumwengbe Str. New lagos Rd, B/C"',
#  'Christian Bar,"NO. 1, Ofumwengbe Str. New Benin, B/C"',
#  'Mr. Moses Cold Room,"NO. 1, Ofumwengbe Str. New Benin, B/C"',
#  'Broker\'s Diary Product,"No. 12, 3rd Cementry Rd, B/C"',
#  'Mrs. Osemwigie Meat Shop,"No. 24, Oba Market Rd, B/C"',
#  'Success Bakery,"No. 140, Erediauwa Str. Off upper SokponbaRd, B/C"',
#  'Piret Hotel,"No. 6, Evbo Minan Str.  Off Sapele Rd, B/C"',
#  'Meridian Lodge,"No. 2, Adenomo Cresent. Off Etete GRA, B/C"',
#  'Mrs. B. Ohenhen,"No. 70, Siluko Rd, B/C"',
#  'Our Lord Bakery,"No. 11, Owenubugie Str. Useh market Rd, B/C"',
#  'Restaurant & Bar,"No. 74, Sakponba Rd, B/C"',
#  'World Circle Bar,"No. 124, 1st East Circular Rd, B/C"',
#  'Mrs. Aigbogun Meat Shop,"No. 94, 2nd East Circular Rd, B/C"',
#  'Mama Kate Restaurant & Bar,"No. 194, Upper Mission Rd, B/C"',
#  'Felona Hotels,"No. 6, Downson Rd, B/C"',
#  'Mrs. G. Egbetu,"Orobator Str. Off 2nd East Circular Rd, B/C"',
#  'Rossy Bakery,"No. 198, MM Way, B/C"',
#  'Mrs. Aimienoho,"No. 20, obasogie Str. 2nd East Circular Rd, B/C"',
#  'Mrs. Okhomina,"No. 20, obasogie Str. 2nd East Circular Rd, B/C"',
#  'RosefSea Food ,"No. 31B, Yorua Str. B/C"',
#  'Ekipec Resources,"No. 31, Yoruba Str. B/C"',
#  'Rossy Bakery,"MM Way, Opp. Ekiosa Market, B/C"',
#  'Jor & Restaurant,"No. 53, Upper Sakponba Rd, B/C"',
#  'Hotel Philomena,"No. 19, Okhoro Rd, B/C"',
#  'Blessed Edozen Bakery,"No. 9, Eyanugie Str. 1st East Circular Rd, B/C"',
#  'Omega Fast Food,"No. 125, new Lagos Rd, B/C"',
#  'Inaynitaz,"No. 13, Ikpokpan Str. Off GRA. B/C"',
#  'Mat Ice Fast Food,"No. 52, Ihama Rd, GRA. B/C"',
#  'Wanatan Garden,"No. 51, Ihama Rd, GRA. B/C"',
#  'Diaca Meal,"No. 74, Ihama Rd, GRA. B/C"',
#  'Saga Hotel,"No. 16, Edo-Osagie Str. GRA, B/C"',
#  'Kiko Hotel,"No. 2, Delta Cresent, Off Ikpokpan GRA, B/C"',
#  'Isno Hotel,"No. 17, Ikpokpan Rd, GRA, B/C"',
#  'Elegance Hotel,"No. 58, Boundry Rd, GRA, B/C"',
#  'Waynitaz,"No. 13, Ikpokpan Str. Off GRA, B/C"',
#  'Ronze Jet Crest Hotel,"No. 78B, Ihama GRA, B/C"',
#  'Vichi Gates,"No. 68,Ihama Rd, GRA, B/C"',
#  'Tunnel Bar,"No. 49, Ihama Rd, GRA, B/C"',
#  'Naomi\'s Garden,"No. 7, Upper Adesuwa Rd, GRA, B/C"',
#  'St Saviour Car Wash Restaurant & Bar,"No. 107, St. Saviour Rd, B/C"',
#  'Ejeke Bakery,"No. 70, Owina Str. Off Sakponba Rd, B/C"',
#  'Notre Dame Pure Water,"No. 75B, Benin-Agbor Rd, B/C"',
#  'Ejike Bakery,"No. 70, Owina Str. Off Sakponba Rd, B/C"',
#  'Imperial Hotel,"No. 38, Edokpolor Factory Rd, B/C"',
#  'Maria Pure Water,"No. 71, Benin-Agbor Rd, Ikpoba Hill,B/C"',
#  'J & H Food Outlet,"No. 10, Oregbeni Str. B/C"',
#  'Queen Sport Food Outlet,"Benin-Agbor Rd, B/C"',
#  'Idi Motel,"Izemwingie Str. Off Benin-Agbor Rd, B/C"',
#  'Mania Hope Food Outlet,"Oregbeni Estate, Benin-Agbor Rd, B/C"',
#  'Rins Exclusive Restaurant,"Ogbesun Qtrs, off Benin-Agbor Rd, B/C"',
#  'Reo Guest House,"No. 166, ikhunoro, Off Benin-Agbor Rd, B/C"',
#  'oghosa Pure Water,"No. 1, oghosa Close, Off Benin-Agbor Rd, B/C"',
#  'O & G Table Water,"Iguomo, Benin-Agbor Rd, B/C"',
#  'Morning Glory Bakery,',
#  'Sizzler Fast Food,"Benin-Agbor Rd, B/C"',
#  'Estate Hotel,"No. 1, Oregbeni Estate, Benin-Agbor Rd, B/C"',
#  'Dum Bird Food Outlet,"Oregbeni Estate, Benin-Agbor Rd, B/C"',
#  'Metro Holiday In,"Behind Guinness PLC. Ikpoba Hill, Benin-Agbor Rd, B/C"',
#  'Egede Food Centre,',
#  'Mama Devine resturant,"Oregbeni Estate hotel road, Benin City."',
#  'Popis Corner,"No. 71, Mission road B/c."',
#  'Star Corner,Ifon road off Idahosa str. B/c.',
#  'Water for real,"No. 10, Upper Mission road by New Benin Market B/c."',
#  'Food Outlet,"No. 12, Edokpolor, off Benin-Agbor road, B/c"',
#  'Furmigation service.,"No. 125, Ikpoba hill, B/c"',
#  'GT Buttered Bread,"No. 9, Ofungbe str. Off Sapele rd. B/c."',
#  'Face 2 Enterprise,"No. 122, Benin-Agbor road, Ikpoba hill."',
#  'Mama Otibhor Resturant,"No. 124, Benin-Agbor road, B/c"',
#  'RESTAURANT AND BAR,"10, Edokpolor House"',
#  'Palm wine Joint/Joint,"Plytmouth road, B/c."',
#  'Omega Resturant and Bar,"No. 125, Uselu-Lagos Rd. B/c."',
#  'Fried Chemicals.," No. 46, Lagos Road str. B/c"',
#  'Austine O shop,"No. 16, Ibiewe str. B/c"',
#  'Kelly Building chemical shop,"No. 13, 2nd Ibiwe str. B/c"',
#  'Mama Nosa Meat shop,"No. 16, Yoruba str. off New Lagos, B/c"',
#  'Amala Spot,"No. 137, New- Lagos Road, B/c"',
#  'Ola Hesomi resturant ,"No. 137, New- Lagos Road, B/c"',
#  'Paliament Bar,"No. 83, Wire Road, B/c"',
#  'Mela Motel,"Mela motel Road, B/c"',
#  'No Country man fast food,"Textile mill road, B/c"',
#  'Mikes Bakery,"Evbareke, B/c."',
#  'Diamond Hieght Hotel,"No. 10, Irubi st. B/c"',
#  'Efex Hotel,"No. 102, Uselu-Lagos road, B/C"',
#  'Talk of Tale City guest House ,"No. 38, Dawson  Road, B/c"',
#  'Hotel Delto,"No.3, Imato Cresent, off Wire road, B/C"',
#  'Etinosa Resturant & Bar ,"Off Oselo-Lagos road, B/c"',
#  'Mr Biggs Fast Food,"No. 102, Uselu-Ugbowo Lagos road, B/c"',
#  'Brother Bar,"No. 30B, Wire road, B/c"',
#  'GT Fast Food,"No. 84, Uselu-Lagos Road, B/c"',
#  'Mat Ice Fast Food,"No. 167B, Uselu- Lagos Road, B/c"',
#  'Kaydes Fast Food,"Uselu-Lagos Road, B/c"',
#  'Haven Hotel,"No. 3, Igbinovia Drive off Uwagboe Rd. B/c"',
#  'Food Outlet,"No. 58, Wire Road. B/c"',
#  'Food Outlet,"No. 1, Ofunmwegbe St. B/c"',
#  'Country Side Hotel,"No. 10, Aimamiegbon,Ainiueiwa st. off Uselu Rd. B/c"',
#  'Food Outlet,"No. 88, Uselu-Lagos Rd. B/c"',
#  'Mayro Water Fatory ,"Etete Rd, GRA, B/c"',
#  'Beer Palour Bar,Akenzua St. B/c',
#  'Benny Furmigation Service,"No. 125, Ikpoba hill, B/c"',
#  'Cremes Suites/Hotel,"No. 2, Blessed Avenue off Boundary Rd,B/c"',
#  'Boston Hotel,"No. 1, Oguigo Avenue, GRA. B/c"',
#  'God\'s Grace Backery,"No. 34, Etinosa st. off Upper Lawani St. B/c"',
#  'Fortune Bakery,"No. 38, Eweka st. New Benin, B/c"',
#  'Eze Marue Lous Bakery,"No. 39, Dandy st. off Okhoro st. b/c"',
#  'Tessy Bakery,"No. 3, Aghehoguwa st. off Eagle Furniture, B/c"',
#  'Aunty Cecilia Buttered Bread ,"No. 5, Aken Osifo st. off Edaiken School Rd. B/c"',
#  'PA Bello ,"No. 2,  first Ibiwe st. B/c"',
#  'Iyayi Fast Food,"Iguosa Village, Benin- Lagos Rd, B/c"',
#  'Precious Palm Royal Hotel,"Benin Lagos Rd, B/c"',
#  'Country Side Hotel,"No 10, Ainiueiwa st. off Uselu Rd. B/c"',
#  'Legend Bar,"No. 234, New Lagos Road, Benin City"',
#  'Ozino\'s Bakery,"No. 10, Ighedosa off Obaminoyi st. off upper sakpomba st. B/c"',
#  'God Det Bakery,Aladhan str. off Dumez Rd. B/c',
#  'Blue Star Fast Food,"No. 206, Upper Siloko Road ,B/c"',
#  'Madam Chicken Fast Food Outlet,"Uwelu spare part market, B/c"',
#  'Piccadilly Bar,"No 110, Sakpomba Road. B/c"',
#  'Andy Frozen meat shop,No.100 Sakpomba Rd. B/c',
#  'Odaro Buttered Bread,"No. 6, Ekwouare str. off MM way, B/c"',
#  'Cold Room,"No.1 Upper Lawani, New Benin, B/c"',
#  'Abisco ,"No.8 Benevolent st. off Obasuyi st Uwelu, B/c"',
#  'Peace Settings Guest House,No.31 Ozanere st. B/c',
#  'star Corner,"No. 31 Edo lane, MM way, B/c"',
#  'Wisdom Bakery,"No. 2, Okungriwa-Priri"',
#  'BJ Bread ,"No. 11, Eweka Str. off upper Siloko Rd. B/c"',
#  'Samphim Hotels,"No. 5, Km5, Benin - Auchi Road Road, B/c"',
#  'Grace Erabor,"No. 100, Edo lane, off MM way, Benin City"',
#  'Blue Star Fast Food,"No. 205, upper siloko Rd. B/c"',
#  'Motuko Bakery,"Benin Lagos Rd, Beside ITV, B/c"',
#  'Home Sweet Home Resturant,"No. 42, The limit Rd off sapele rd. B/c"',
#  'Obern Concepts Furmigation Outfits,"No 42, Godwin Abebel way (D limt) Road off Sapele Rd. B/c "',
#  'Ritchy Bread Bakery,"Plot 19, Federal Housing Estate, B/c"',
#  'Wellington Royal Hotel,"Uguobadia Avenue, off Etete Rd, GRA. B/c"',
#  'Jerry Bakery,"No. 2, Aibuedefe st. off 1st Uogbor st B/c"',
#  'Afes Table Water,"No. 12B, Osagie off Dumez Rd. B/c"',
#  'Ivory Kitchen,"No. 2, Faith drive off Faith Rd. B/c"',
#  '"Sweet -""B"" IN","No. 3, Odekhinan Avenue off 2nd Ugbor Rd. GRA. B/c"',
#  'Bros Bakery,"No. 10, Onaghisee st. off upper Sakpomber Rd. B/c"',
#  'The Andaluz Car wash/Bar,"No. 4, Trinity way, off ugbor rd. B/c"',
#  'Shoneys Bendevou Fast food,"No. 11 upper Adesuwa, GRA. B/c"',
#  'Oriakeh Bar,"No. 28, Oko Central, GRA. B/c"',
#  'Uncle Franic Bakery,"No. 10, Ohen Street Ekae Km 8 Saplele Rd"',
#  'Red velt vet Hotel,"Faith Drive off way GRA, B/c"',
#  'Due Palace Bar,"No. 32, Oko Rd along airport road,B/c"',
#  'Sharpex Guest house,"No. 13, Obashan st. off oko central rd, GRA. B/c"',
#  'Perino Hotel ,"No. 5, Boundary rd. GRA, B/c"',
#  'Double Blessing Table water,"No. 108, Sapele Road, B/c"',
#  'Mat Ice Fast Food,"No. 52, Ihiama st. GRA. B/c"',
#  'Option-One Hotel,"No. 62, Ihiama st. GRA. B/c"',
#  'Ken Concept Bar,"Ihama str. GRA, B/c"',
#  'Wantan Garden,',
#  'Vichi Gates Hotel,"No. 68, Ihama Road, GRA. B/c"',
#  'Fedgad Bar & Restaurant,"No. 17, JBS Estate off Boundary road, B/c"',
#  'Ronze-Jet Crest Hotel,"No. 78b Ihama rd, GRA. B/c"',
#  'Mayo Table Water,"No. 6 Etete Road off Adesuwa Rd. GRA, B/c"',
#  'Baden Baden Executive suite & Halls,"Sapele Road, Benin city"',
#  'The Limit Motels LTD,"Godwin Abey way, off Sapele rd. B/c"',
#  'De- City Table water ,"Plot 1, Evbuoriaria, off sapele rd. B/c"',
#  'Absel Ttable water,"km 8, Benin Sapele road, B/c"',
#  'Good days Guest House ,"No. 7, Abusomwan st. off Idahosa, B/c"',
#  'Network Recreation ,"No. 2, Akenzua st. B/c"',
#  'Sakpomba Parliament,No. 21 sakpomba rd.  B/c',
#  'Chosen Bakery,"No. 8, Ogbelaka lane, B/c"',
#  'The Dinner Restaurant and Bar,"No. 18, Sokpomba rd. B/c"',
#  'Nosaru Bakery,"No. 1,  Yoruba st. B/c"',
#  'Restaurant and Bar,1st East circular rd. B/c',
#  'Isoken Food Oulet,"1, 2nd East Circular Road"',
#  'Uwa Table Water,"45, Amadasun Street off Etete Road G.R.A Benin City"',
#  'Mike Bakery,"18, Alimere Street off Textile Mill Road"',
#  'Our Choice Table Water,"20, Uyi-Ekpen Street off Akpakpava Benin City"',
#  'Popular Bakery,"1B, Wisdom Street Benin City"',
#  'Iyayi Table Water,',
#  'Honey Rainbow Bakery,',
#  'Money Glory ,"112, 1st Upstairs Road Benin City"',
#  'Insight Bakery ,"102b, Siluko Road,Benin City"',
#  'The Owner Star Bakery ,"Omoregbe Street, off Siluko Road, Benin City "',
#  'Melo Bakery ,"Omigie Street, off Oromiyan, Benin City"',
#  'Eddy Baga Internationa LTD Foundation Outfit,"41, Sokponba Road, Benin City"',
#  'Ohallic NIG.LTD," 2, Ogbelaka Street, off Sapele, Road Benin City"',
#  'Wagosa Table Water,"54, Upper Ekenwa Road Benin, City"',
#  'Estate Hotel ,"Ikpoba Hill, Benin City"',
#  'Imeral Regency Hotel,"35, Jemila Road, Ikpoba Hill, Benin City"',
#  'Jemila Hotel,"8, Edokpolor Factory Road, Benin City"',
#  'Jigger Guest House,"Aroko Estate, Ikpoba Hill, Benin City"',
#  'Benco Chemical ,"63, Ehaekpen Street, Benin City"',
#  'Marvelous Hotel ,"1, Aroko Street, Ikpoba Hill, Benin City"',
#  'Spanish Bakery ,"19, Akugbe Street, Ikpoba Hill, Benin City"',
#  'Central Hotel ,"76, Akpakpava Road, Benin City"',
#  'Peak Hotel ,"222, Old Benin-Agbor Road, Ikpoba Hill, Benin City"',
#  'Honey Rainbow Bakery,"Old Benin-Agbor Road, Behind Motor Park, Benin City"',
#  'Rins Execlusive Hotel,"13, Igbinosa Street, Ikpoba Hill, Benin City"',
#  'REO Guest House,"166, Old Agbor Road, Ikpoba Hill, Benin City"',
#  'Hotel Doris Dey,"29, Benin-Agbor Road, Benin City"',
#  'Standard Guest House,"Ikpoba Hill, Benin City"',
#  'Ify Guest House,"2, Idalo Street, Ikpoba Hill, Benin City"',
#  'Sonia  Guest House ,"2, Idalo Street, Ikpoba Hill, Benin City"',
#  'Daddy J Hotel,"J.Hotel Street, Ikpoba Hill, Benin City"',
#  'Elegance Hotel LTD,',
#  'Ugo Bakery ,"17, Osaro Street, Ikpoba Hill, Benin City"',
#  'Eche Bar,"102, Benin-Agbor Road, Benin City"',
#  'Maria Pure Water ,"Benin-Agbor Road, Benin City"',
#  'Hotel Reliance ,"13, Benin-Auchi Road, Benin City"',
#  'Ritchy Bakery ,"Federal Housing Estate, Benin City"',
#  'Osaro Bakery,"Federal Housing Estate, Benin City"',
#  'Notre Dame Pure Water,"75b, Benin-Agbor Road, Benin City"',
#  'Safari Guest House,"75, Benin-Auchi Road, Benin City"',
#  'Big Joe Pure Water,"49, Benin-Auchi Road, Benin City"',
#  'Basis Royal Grand Hotel,"144, Benin-Auchi Road, Eyaen, Benin City"',
#  'Rialto Hotel ,"1, Rialto Close, Eyaen, Benin-Auchi Road, Benin City"',
#  'Zafike Royal Hotel,"Km 8, Benin-Auchi Road ,Benin City"',
#  'Samphino Hotel ,"Eyaen, Benin-Auchi Road, Benin City"',
#  '2+2 Guest House ,',
#  'Lixbor Hotel,"Sakponba Road, Benin City"',
#  'Debbies Kitchen,"61, Sokponba Road, Benin City"',
#  'Sizzler Fast Food,"3, Sokponba Road, Benin City"',
#  'Mat-Ice,"12, Sokponba Road, Benin City"',
#  'Network Relaxation ,"2, Aruosa Stree,t Benin City"',
#  'Maustine Place ,"6, Upper Mission Extension, Benin City"',
#  'Aibije Hotel ,"30, Upper Mission Extension, Benin City"',
#  'Paulingo Plaza ,"8, Guest House, Upper Mission Extension, Benin City"',
#  'Babalarun Bar ,"59, Sokponba Road, Benin City"',
#  'Kydee Centre ,"59, Airport Road, Benin City"',
#  'Supreme Guest House ,"59, Airport Road, Benin City"',
#  'Samsy Hotel,"5, Ben Oni Stree,t GRA, Benin City"',
#  'Tetrazzin Chicken Restaurant,"70, Airport Road, Benin City"',
#  'De Marriot Hotel ,"4, Jemide Avenue, off Giwa Amu Street, GRA, Benin City"',
#  'Prestige Hotel ,"1, Oni Street, GRA, Benin City"',
#  'Mr Food Fast Food ,"1, Ihama, off Airport Road, Benin City"',
#  'Rossy Bakery ,"198, M.M Way, Benin City"',
#  'Envoy Hotel ,"4, Osagie Avenu,e off Giwa Amu, GRA, Benin City"',
#  'Omoritana Hotel ,"13, Oni Street, GRA, Benin City "',
#  'Constantials Hotel,"24/26, Airport Road, Benin City"',
#  'Mana Table Water,',
#  'Tarex Place ,"6, Edobor Osula Street, off Oni Street, GRA, Benin City"',
#  'Envoy Hotel ,"4, Osagie Avenue, off Giwa Amu, GRA, Benin City"',
#  'Talk of the City Hotel,',
#  'Hotel Felona ,"Dawson Road, Benin City"',
#  'Blessed Edo Bakery ,',
#  'Akpakpava Bakery,"Old Western Road, Benin City"',
#  'Benin Motel Plaza,"GRA, Benin City"',
#  'Zee Louge,"97, Boundary Road, GRA, Benin City"',
#  'Katori\'s Bamboo House,"34, Boundary Road, GRA, Benin City"',
#  'Courtyard Hotel,"15, Boundary Road, GRA, Benin City"',
#  'Creme Suites&Hotel ,"26, Blessed People Avenue, GRA, Benin City"',
#  'Fed Guard Hotel ,"7, JBS Estate, GRA, Benin City"',
#  'Bibi Motel ,"72, Boundary Road, GRA Benin City"',
#  'Rity Garton Hotel,"64, Boundary Road, GRA, Benin City"',
#  'Diamond Travel Hotel,"11B, Urubi Street, Benin City"',
#  'Wakki Guardinu,"19, Adesuwa Road, GRA, Benin City"',
#  'Kreeds Hotel ,"41A, Adesuwa Road, GRA, Benin City"',
#  'Rea Africana Restaurant,"1, Azige Crescent, GRA, Benin City"',
#  'Car Wash & Bar,"21, Adesuwa Road, GRA, Benin City"',
#  'Fej Restaurant ,"12, Boundary Road, Benin City"',
#  'Benin Continental Hotel,"11b, Ikpokpan Avenue, GRA, Benin City"',
#  'Waynitaz Food ,"13, Ikpokpan Road, GRA, Benin City"',
#  'Kiko Hotel ,"2, Delta Crescent, GRA, Benin City"',
#  'Isno Hotel ,"17, Ikpokpan Road, GRA, Benin City"',
#  '40/40 Sport & Bar ,"Adesuwa Road, GRA Benin City"',
#  'Farmer\'s Sakponba ,"4, Complex"',
#  'Time and Season Bakery ,"38, M.M.Way, Benin City"',
#  'Niki Manifact-Uring Comp.LTD ,"Ogba Road, Benin City"',
#  'Okaro Table Water ,"44, Iyekekpolor Housing Estate, Benin City"',
#  'The  Coon Yoghurt,"10, Airuedomwinya Avenue, Iyekogba Housing Estate, B/City"',
#  'Omo -Adoni Odighiri Fumigation Outfit ,"7A, Ikpoba Slope, Benin City"',
#  'mrs Iyamu Cold Romm,"92, 2nd East Circular Road, Benin City"',
#  'MRS Owens Cold Room," 73, 2nd East Circular Road, Benin City"',
#  'Mrs C &G Cold Room,"81, 2nd East Circular Road, Benin City"',
#  'O &R Cold Room,"83, 2nd East Circular Road, Benin City"',
#  'Mrs M Imasun Cold Room,"7b, 2nd East Circular Road, Benin City"',
#  'Westey Hotels,"2 Aguele Drive, Off Akhiobare, GRA, Benin City"',
#  'Government Reservation,"48, Akhiobare Street, GRA, Benin City"',
#  'Cold Room,"2nd East Circular Junction, Benin City"',
#  'Mrs Grace Agbogi Meat ,"4, Ogiamiem Street, Benin City "',
#  'Mrs Enabulele Cold Room ,"Yoruba Street, Benin City"',
#  'BI  LO International Meat Shop,"Yoruba Street, Benin City"',
#  'Mrs bello Osagie Cold Room,"Off Upper Lawani Street, Benin City"',
#  'mama Junior Cold  Room,"Upper Lawani Street, Benin City"',
#  'B7 meat Shop,"Yoruba Street, Benin City"',
#  'Cold Room,"Upper Lawani Junction, New Benin ,Benin City"',
#  'Sizzler Fast Food,"Sakponba Road, Benin City"',
#  'Mrs Igbinewera Meat Shop,"93, 2nd East Circular Road, Benin City"',
#  'Mrs Adesuwa Meat Shop,"91, 2nd East Circular Road, Benin City"',
#  'Foreign Lady Meat Shop,"91, 2nd East Circular Road, Benin City"',
#  'One Love Meat Shop,"91, 2nd East Circular Road, Benin City"',
#  'Mrs Giegbefu Mwen Cold Room,"1b, Ogiamien Lane, Off 2nd East Circular Road, Benin City"',
#  'Car Wash & Bar,',
#  'Mrs B meat Shop ,"93, 2nd East Circular Road, Benin City"',
#  'Winsa Frozen Meat Shop,"2nd East Circular Junction, by Sokponba, Benin City"',
#  'Mr Egharevba Cold Room ,"19, Orobaton Street, Benin City"',
#  'Mr Fred C \\Y Cold Room,"Evbarunegbefu  Street,  Benin City"',
#  'Cold Room ,"EVbarunegbefu  Street, Off Lucky Way, Benin City"',
#  'Mr Enabulele Cold Room,"12B,  Obasogie Street, Off 2nd East Circular Road, Benin City"',
#  'Mrs Okuns Cold Room,"23, Evba, Ubefo Str. Benin City"',
#  'Mr Uyiekpen Cold Room,"9, 2nd East Circular Road, Benin City"',
#  'Osawe Cold Room,"79, 2nd East Circular Road, Benin City"',
#  'Mr Joseph Unufe Febhns,"105, Sokponba Road, Benin City"',
#  'Mania Enoghayin Cold Room,"105, Sokponba Road, Benin City"',
#  'Rito Cold Room,"105, Sokponba Road, Benin City"',
#  'Mania Bose Cold Room,"90, 2nd East Circular Road, Benin City"',
#  'Mrs A Osayan De Cold Room,"18,  Evbarunegbefu  Street,  Benin City"',
#  'Rendekhi Royal Hotel,"6, Ihenuri, off Ihania str. GRA, Benin City"',
#  'Pepper Rice Resturant,"8, Adeyan Crescent, Benin City, "',
#  'Consulate Bar,"19, Ikpokpon Road, GRA, B/City"',
#  'Chioce Gate Hotel,"11, Neka Street, GRA, B/City"',
#  'Hotel Excutive,"40, Sabuohen Close, Off Ihania Street, B/City."',
#  'Uyi Grand Hotel ,Aidevaon Street Off Ihania Street. B/City',
#  'Alice Hotel ,"24, Imureze, Off Upper Adesuwa Rd. Benin City"',
#  'Wantan Garden,"51, Ihama Road, GRA, B/City"',
#  'Kems Concept,"37, Ihama Road, GRA, B/City"',
#  'Useni Hotel And Suites68,"68, Ihama Rd, GRA, B/City"',
#  'P.F Quality Hotel,"6, Ale Street, Off 180 Upper Sokponba Rd, B/City"',
#  'Citizen Hotel,"42, Uwa Str. Benin City"',
#  'Aso Time Bar,',
#  'Otonie Guest House,"4, Otonia Street,B/City"',
#  'Chemijar Hotel ,',
#  'Mrs Otamere Meat Shop,"27, MM Way, Benin City"',
#  'The Royal Marble Hotel,"22, Ihama GRA B/City"',
#  'Florence Imolorhe Meat Shop,',
#  'Patno Resturant And Bar,"5, Ogbelakar Str. B/City."',
#  'Good Shephard Guest House,"14, Amure Str. Opposite Ebeneza Primary School, Benin City"',
#  'Chioce Gate Hotel,"11, Neka Street GRA, B/City"',
#  'Evelyn Meat Shop,"18, Oba Market Road, Benin City"',
#  'Aimosa Meat Shop,"02, Oba Market Road, B/City"',
#  'Mrs Amen Ojo Meat Shop,"24, Oba Market Road, B/City"',
#  'Madam Carry Go Meat Shop,"24, Oba Market Road, B/City"',
#  'Mrs Topa Meat Shop,"24, Oba Market Road, B/City"',
#  'No Name Meat Shop,"18, Oba Market Road, Benin City"',
#  'Mrs Agboola Meat Shop,"22, Oba Market Road, B/City"',
#  'Mama Emeka Restaurant ,"Vegetable Market, B/City"',
#  'Sunny Meat Shop,"24, Oba Market Road, B/City"',
#  'Ivory Kitchen,"27, Airport Road, B/City"',
#  'Senaga Guest House,"31, Airport Road, B/City"',
#  'Meat Shop,"22, Oba Market Road, B/City"',
#  'Emeka Meat Shop,"22, Oba Market Road, B/City"',
#  'Vicland Venture Kitchen,"Coca-Cola, Benin City"',
#  'Ozinon Restaurant ,"1, Igbinedion Street, B/City"',
#  'Olivia Table Water,"51, Arenzen Str. B/City"',
#  'Debbis Fast Food,"61, Sakponba Road, B/City"',
#  'Derino Holtel,"I5, Boundary Rd, GRA, B/City"',
#  'Wauossa Table Water,"I54, Upper Ekemwan Road, B/City"',
#  'Unibake Bakery Table Water,"9, 2nd Victory Lane, B/City"',
#  'Pat Meat Shop,"34, Oba Market Road, Benin City"',
#  'Uche Iwuozo Meat Shop,"18, Oba Market Road, Benin City"',
#  'Oghosa Meat Shop,"18, Oba Market Road, Benin City"',
#  'F.O Meat Shop,"18, Oba Market Road, Benin City"',
#  'Lynnfida Guest House,"Osabuohien Close, Off Ihama GRA, B/City"',
#  'Jenilla Hotel,"8, Edokpolor Factory Road, Ikpoba Hill, Benin City"',
#  'Lisbor Hotel,"4, Sokponba Rd, Benin City"',
#  'Royal Bakery,"4, Iyobosa St, Benin City"',
#  'Hotel Felona,"Downson Rd, B/City"',
#  'Aso Time Restaurant And Bar,"5, Ihama GRA, B/City"',
#  'Jeffosa  Suit/Guest House,"22, Anuwa Str. Off Upper Sokponba Rd. Benin City"',
#  'Winner Chort,"93, Lagos Str. Benin City"',
#  'Stainles Resturant,"37, Costain Road B/City"',
#  'Central Hotel,"76, Akpakpava Road, B/City"',
#  'The Royal Marble Hotel ,"33, Ihama GRA, B/City"',
#  'Nasco Bakery,"117, Upper Mission Road, B/City"',
#  'Ranzeki Hotel,"6, Ihenuuriri Str. Gra B/City"',
#  'Toc Hotel ,"38, Dowson Road, B/City"',
#  'Diamond Height,"11, Urubi Street, B/City"',
#  'Nosakhare Baker,"1, Nosakhare St, B/City"',
#  'Vicks Fast Food ,"36, Ihama GRA, B/City"',
#  'Consulate Bar,"19, Ikpokpan Rd, B/City"',
#  'Isno Hotel,"17, Ikpokpan Rd, GRA, B/City"',
#  'Pire Motel,"Evbomwan Close, Off Sapele Rd, B/City."',
#  'Wayitaz Fast Food ,"13 Ikpokpan Rd, GRA, B/City."',
#  'Two Sisters Hotel,"113, Akpakpava Road, B/City"',
#  'Fce Bakery,"15, Independence, Upper Sokponba Rd, B/City"',
#  'Obaro Guest House ,"66, Old Benin-Auchi Rd, B/City"',
#  'Osagide Guest House ,"108, Old Benin-Auchi Rd, B/City"',
#  'Aduwawa Guest House ,"39, College Rd Aduwawa, B/City"',
#  'B Hotel,"200, Ekenwan Rd, Benin City"',
#  'Reliance Hotel,"13, Efionayi Rd, Off Aduwawa Rd, B/City."',
#  'Mr Votel Hotel,"1, Agbontaen Rd, Aduwawa, Benin City"',
#  'De Palce Bar,"121, Igun St. B/City."',
#  'Honie Base Bar,"53, Wire Rd B/City"',
#  'Greater Love Butter Bread,"12, Akenzua Street Off Okhoro Rd B/City"',
#  'Bj Bread ,"11, Eweks Off Upper Siluko Road, B/City"',
#  'Christo Bakers,"124, Uwelu Rd, B/City."',
#  'Oviane Bakery,"27, Eweka Off Upper Siloku "',
#  'Chemijar Hotel ,"1, Ogiva, Ogivaba Avenue Off Upper Uwa B/City"',
#  'Eldorado Hotel,"08, Neka Street Off Ugbor, Gra B/City."',
#  'Food Outlet ,"10, Iwehen St, B/City."',
#  'Edina Pure Water,"18, Ikpopan Rd, Gra B/City"',
#  'Gt Fast Food Plaza,Benin Agbor Road',
#  'Model Restaurent  And Elegance Hotel,"58, Boundary Rd, B/City"',
#  'Samsy Hotel ,"2, Hospital Rd, Gra"',
#  'Corea Fast Food,132 2nd East Circular Rd.',
#  'Perfect Place Bar,"179, Siluko Rd"',
#  'Nigeria Man And Bar,"7, Oguola St Off Mission Rd, B/City."',
#  'Food Outlet,"95, Wire Road B/City."',
#  'Food Outlet ,"28, Ready, 69 Akpakpava, B/City"',
#  'Chinedu Baker,"52, Siluko Rd, B/City"',
#  'Ajero Restaurant And Bar,"50, Siluko Rd, B/City."',
#  'NAME ,LOCATION,STATUS',
#  'Ogba Zoo,Benin City,functional',
#  'National Museum,Benin City,functional',
#  'Ramat Park,Benin City,Abandoned',
#  'Victor Uwaifo Tourist Pallazo,Benin City,functional',
#  'Chief Priest Osemwengie Ebohon Botanical Garden,Benin City,functional',
#  'Captain Philips Tomb Site,"Ugbene, Near Benin",Abandoned',
#  'Eze nemumkpo (Mystery River),"Ughoton, Near Benin",functional',
#  'Okomu National Park,Udo Ovia South West,functional',
#  'Ososo Tourist Centre,"Ososo, Akoko Edo LG",functional',
#  'Lampese Crocodile Lake,Akoko Edo LG,functional',
#  'Ojah Claypot moulding Industry,Akoko Edo LG,functional',
#  'Somorika Hills and Caves,Akoko Edo LG,functional But Underdeveloped',
#  'Okpilla Cement Factory,Etsako East LGC,Abandoned',
#  'Fugar Caves,Etsako Central LGC,Underdeveloped',
#  '"Udo Colonial Rest House, Udo",Igueben LGC,Abandoned',
#  '"Sakponba Resort, Sakponba",Orhionmwon LGA,Underdeveloped',
#  '"Oba Akenzua Cultural Complex, Benin City",Oredo LGC,Developed and Functional',
#  '"Agenebode Waterside, Agenebode",Etsako Central LGC,Underdeveloped',
#  '"Ilushi Waterside, Ilushi",Esan South East LGC ,functional But Underdeveloped',
#  'Ehor Vegetable and Fruit Market,Uhumwode,functional',
#  '"Igun Bronze Casting Industry, Benin",Oredo LGC,functional But Underdeveloped',
#  '"Ebony Wood Carving Industry, Benin",Oredo LGC,Functional',
#  '"Oba Palace and Walls, Benin",Oredo LGC,Functional',
#  '"Benin Moat and Walls, Benin",Oredo LGC,Abandoned',
#  '"Ogiamen\'s Palace, Benin City",Oredo LGC,functional',
#  '"Amahor Waterfalls, Amahor",Igueben LGC,Underdeveloped',
#  'College of Physical Education,Afuze,Functional',
#  'Ikpoba River Dam,Ikpoba Okha LG,Underdeveloped',
#  '"Aruan Statue, UDO",Ovia South East LGA,functional But Underdeveloped',
#  'Edegbake Cave,Etsako Central LGA,Functional',
#  'NAME OF PROPRIETRESS AND PROPRIETORS,FULL NAME OF ORGANIZATION AND CHILDREN HOME.,PHONE NUMBER,DETAILED ADDRESS OF ORGANIZATION.,L. G.A.,NO. OF MALE ORPHAN,NO. OF FEMALE ORPHAN,TOTAL NUMBER',
#  'Mrs. Esther Ogbe,Edo Orphanage Home.,8060427189,"Usama Street, Benin City.",Oredo,10,30,40',
#  'Princess Kate  Oronsaye,Oronsaye Orphanage Home.,8030779086,"81, Owina Street, Off Agbado Market Benin City.",Oredo,13,11,24',
#  'Madam Uyiosa,Uyiosa Orphanage Home.,8037672769,"No. 2, Obayagbonya Street, Off Upper-Sakponba Road, Benin City. ",Ikpoba-Okha,6,15,21',
#  'Sir Idehen,Corner-Stone of Hope Orphanage Home.,8057493900,"No. 9, Omorogbe Street, Off Egbu Street, Behind St. Patrick�s Catholic Church Ugbowo, Benin City.",Egor,5,9,14',
#  'Pastor & Mrs F.U. Igbinosa,Compassion Orphange Home.,8166827290,Assemblies Camp Street by Uyi Edo.,Oredo ,12,14,26',
#  'Mrs. G. Bello,Amadin Orphanage Home.,8037934090,"123/140, Lagos Street, Benin City.",Oredo,20,22,42',
#  'Madam Abeni,Abeni Orphanage Home.,-,"No. 40, Federal Road, Off Okhoro Road, Benin City.",Oredo,20,15,35',
#  'Madam Davies,"No. 2 , James Ogbose Orphanage Home.",8102445746,"Street off Ogbemudia Street, Iwogban.",Ikpoba-Okha,2,8,10',
#  'Dr. Oriafo,Good Luck Orphanage.,8053143881,"Dr. Oriafo Medical Centre, New Road, Uromi.",Esan North East,0,1,1',
#  'Dr. Osigbemhe,Good will Orphanage Home (Osigbembe).,8053973990,"99, Igbe Road, Auchi.",Etsako West,2,2,4',
#  'Evangelist  Edokhaisomi Bello,Christ Family Orphanage Home. ,8070575919,"Otoukwe Quarters, Agenegbode.",Etsako East,5,8,13',
#  'Mrs. D. Ogbeide,Omosefe Orphanage Home.,8036108613,"No. 4, Bello Osagie Street, Off Akpakpava Street, Benin City. ",Oredo,4,5,9',
#  'Rev. Fr. Denian Adizie,Holy Spirit (Mary Land) Orphanage Home. ,8076635886,"Egoro-Amede, Ekpoma.",Esan west,13,11,24',
#  'Solomon Folorunsho,International Christian Centre for Ministry.,8033441246," No. 45, Umanmwen Street, Ogida Quarters, Benin City. ",Egor,64,119,183',
#  'Mrs. M. Abulu,Courage Orphanage Home.,8052729401,"PHCN, Power line of Ihumudumu Road, Ekpoma.",Esan West,2,3,5',
#  'Sir & Lady Cole,Sir & Lady Cole Orphanage Home.,8033600178,"T.V. Road, Benin City.",Oredo,4,12,16',
#  'Mrs. C.I. Edoka,God�s Love Orphanage Vulnerable Children Home.,8037751062,"Okugi  Village, Okpekpe,  Etsako.",Etsako East,11,4,15',
#  'Rev. Fr. Adolphus Umechukwu,Mary Immaculate Children�s Home. ,8085477973,"Behind St. Michael the Archangel Prayer Ministry  Ikhuenino, After  By-Pass,  Benin Agbor  Road,  Benin City. ",Ikpoba Okha,9,20,29',
#  'Rev. Fr. John Bosco Ezehi,Catholic Chess Project.,8053000203,"No. 1, Ezehi Avenue Efandion Quarters, Uromi, Edo state.",Esan North East,33,32,65',
#  'Grace  Iyonawan Oyemwuse,Grace  Iyonawan  Oyemwense Foundation  (Grace House Orphanage).,8102445746,"Plot 200, Scotty Asuen Avenue off Sapele Road, Etete Layout, G.R.A., Benin City.",Ikpoba Okha,2,1,3',
#  'Martha Orphanage Home,-,8136080075,Fugar.,Etsako Central,5,5,10',
#  'Kids  Club  International  Orphanage Home,Kid club International Orphanage Home.,8033420014,Izevbekhae Street Ogbeson Quarters.,Ikpoba �hill,1,1,2',
#  '-,-,-,Benin/Agbor Road after Asemotta Filling Station.,-,-,-,-',
#  'Mrs. Akende,Christ Orphanage Home.,-,"Yaya, Afekhai Street, Old Auchi Road, Igarra.",Akoko-Edo,-,-,-',
#  'Itsoghena (God�s Own) Orphanage Home,-,7062255091,Auchi.,Etsako West,28,18,46',
#  'Iwinosa Orphanage Home. ,Iwinosa Orphanage Home. ,8027195785,"6B, Zabayo street, Off Playmouth Road, Benin City.",Oredo,3,6,9',
#  'Pastor Diego and Agyemans,Rehabilitation of the marginalized Remar Association of Nigeria.,-,"43A, Vincent Asemota, Off Uwasota Ugbowo.",Egor,17,11,28',
#  'Bishop Ike,Temple of Praise Orphanage/Homeless People�s Home.,8183867931,"6, Imuafe Street, Afuze, Owan East.",Owan  East,2,-,2',
#  'Rev. Catherine M. Oghoredafe,E.H.I. Home for the needy,-,Agenebode.,Estasko East,27,17,10',
#  'DESCRIPTION OF PROJECT,LGA,COMPANY ,ADDRESS,PHONE NO,',
#  '"Adolor College, Benin City",Egor,Madona Org. Ltd.,"118, M.M. Way, Benin City",8034187349,',
#  '"Aiwerioba Ogiugo Grammar School, Ugoneki ",Uhunmwode,Brosmax Nig. Ltd.,"25, Oko-Ogba Road, Benin City",8055271295,',
#  '"Ambrose Alli University, Ekpoma",Esan West,Zeppieri Company Nig. Ltd.,"1b, Edaiken Avenue Off Airport Rd. Benin City",8103638863,',
#  'Anegbette Secondary School,Etsako Central,Zacko Dynamic Venture,"Doni Filling Station, Benin-Okene Road",8054827739,',
#  '"Annunciation Catholic College, Irrua",Esan Central,Revere Works W. Africa Ltd.,"100, Sapele Road, Benin City",8028187076,',
#  '"Army Day Secondary School, Auchi (Lot: 1)",Etsako West,Amosim Projects Nig. Ltd.,"2, Ediale St, Btw  Boundary Road.",8036412226,',
#  '"Army Day Secondary School, Bode (Lots: 1 & 2)",Etsako East,Larrywest Int. Ltd.,"62, Akpakpava Street, Benin City",8062610288,',
#  '"Army Day Secondary School, Agenebode (Lots: 3 & 6)",Etsako East,Amosim Projects Nig. Ltd.,"2, Ediale St, Btw Boundary  Road.",8036412226,',
#  '"Army Day Secondary School, Ekenwan Road",Egor,Ruo Global Nig. Ltd.,"1, Agbonifo Street, Ekenwan",8037583414,',
#  '"Army Day Secondary School, Ugbowo (Lots: 1 & 2) ",Ovia  N/East,Aye Danfire Ltd.,"15a, Ojomoh Street",8054019112,',
#  'Asoro Grammar School (Lot: 2),Egor,Fresh Affairs Ltd.,"3, Efedhoma Cresent, Power Line, Oluku.",8097998494,',
#  'Asoro Grammar School (Lots: 3 & 4),Egor,Evolino Nig. Ltd.,"Izegbuwa Cresent, Gra.",-,',
#  'Asoro Grammar School (Lot: 1),Egor,Magic Plus & Automall Com. ,"61, Sakpoba Road",7057400488,',
#  '"Ayogwiri Grammar School, Ayogwiri (Lots: 2 &  4)",Etsako West,Guaraty Service Com.,"60, Mbonu Street, Port-Harcount",-,',
#  '"Ayogwiri Grammar School, Ayogwiri (Lots: 1 & 3)",Etsako West,Mr B. Hotel Ltd.,Jattu-Abuja Road,-,',
#  'Community Primary School,Oredo,Johnson Philis Tech Services,"2, Aviation Way Off Joromi, Benin City",8032312992,',
#  'Dagbala Secondary School (Lot: 3),Akoko-Edo,Uma Ent.Nig. Ltd.,"Odo Round About, Box 26, Ibillo",8037348371,',
#  '"Dagbala Secondary School, Dagbala (Lot: 1)",Akoko-Edo,Olu-Oseh Nig. Ltd.,"8, Omoregbe Street, Off Uselu",8037779830,',
#  'Ebelle Secondary Community School,Igueben,Sandplus Dev. Co. Ltd .,,8064159100,',
#  '"Edeki Grammar School, Otuo",Owan East,Airoe Con. Company Ltd.,"130, New Lagos Road",8033724450,',
#  '"Edokpolo Grammar School, Benin City",Oredo,Positive Ways Nig. Ltd.,"Office Plaza, New Lagos, Benin City",8037005001,',
#  '"Edokpolor Grammar School, Lab, Sch Hall & Toilets (Lot: 5)",Oredo,Edo Omo Motors & Contr.,"212, Upper Siluko Rd.",8055289009,',
#  'Edokpolor Grammar School (Lot: 4),Oredo,Erha Company Ltd.,"40, Express  Avenue, Off Ighosastreet",8091438384,',
#  'Edokpolor Grammar School (Lot: 6),Oredo,Nakhere Nig. Ltd.,,8036683138,',
#  'Edokpolor Grammar School (Lot: 2),Oredo,Osaigho & Sons Ltd.,"226, M.M.Way, Benin City",8079855505,',
#  'Edokpolor S/J Sch (Lot: 3) ,Oredo,O & O Tech Nig. Ltd.,"B7, Forestry Rd,  Benin City",8066836197,',
#  '"Egba Grammar School (Lots: 2, 4 & 6)",Uhunmwode,Iyayi Brothers Ltd.,"12, Aghimien Street, Off Okhoro Rd.",8065068774,',
#  'Egor Secondary School (Lot: 1),Egor ,Ag Zion Ltd. ,"95, Siluko Road, Benin City",8054128883,',
#  'Egor Secondary School (Lot 2),Egor,Snobec Nig. Ltd.,"7, Ihama Rd.",8035508427,',
#  '"Ehor Grammar School, Ehor",Uhunmwode,Nikaro Nig. Ltd.,"113, 2nd Cemetry Road",8034053471,',
#  '"Ekhaguere Primary Schoolool, Ekhaguere G.R.A (Lots: 1 & 2)",Oredo,N.B.H. Nig. Ltd.,"742 &743 Arab Contractors St. Dawaki Extention Layout, Abuja FCT",8032646015,',
#  'Ekperi Grammar School,Estako Central ,Bradumed Nig. Ltd.,"50, Airport Road, Benin City",8023926147,',
#  '"Elaho Grammar School, Eguaeholor",Uhunmwode,Steve Imafidon & Sons Ltd.,"176a, 2nd East Circular",8034035687,Stop Work Letter 8/1/14',
#  'Emotan College,Oredo,Rick Foster Emuze Ltd.,"Offiah Plaza, New Lagos Road",8037005001,',
#  '"Emu Grammar School, Emu",Esan S/E,Omas Investment Nig. Ltd.,"10, Dokun Ogundipo Ave. Iddi-Roko",8033334440,',
#  'Evbosi Mixed Secondary School,Orionmwon,Sammed Global Ser.,"16, Adesuwa Grammar School Road",8081370747,',
#  'Eyaen Primary School,Uhunmwode,Kusoben Nig Ltd.,"26b, Akwuzu St, Lekki.",7065243049,',
#  'George Idah Model Primary School,Oredo,Igharo Evbuomwan & Coy.,"156, Uwelu Road.",8029348231,',
#  '"Holy Trinity Grammar School, Sabo",Owan West,Pa-Etos Ltd.,"Jima Plaza (3rd Floor ), Abuja",8036404250,',
#  'Idia College Benin City,Oredo,Cremona Construction Com.,"Plot 5a, Kadenda Ind. Layout Kaduna",8058992051,',
#  'Idogbo Secondary School,Ikpoba-Okha,Prince Link Venture,"11, Nneka Street, Benin City",8023150006,',
#  'Idunwele Grammar School,Esan West,Fkc International,"23, Erewele Street, Irrua ",8023350887,',
#  'Igbanke  Mixed Secondary School Igbanke (Lots: 1 & 2),Orhionmwon,Hexagon Networks Ltd.,"2a, Golf Course Road, Benin City",7051906284,',
#  'Igieduma  Grammar School,Uhunmwode,Math Ehis Nig. Ltd.,"15, Benoni Road,  Benin City",8033736228,',
#  'Igueben Grammar School,Igueben,Morifa Ltd. ,"20, Ihama Road G.R.A",8078654178,',
#  '"Iguediaken Secondary School, Ekiadolor",Ovia N/East,Next Focus Intelligence Ltd.,"10, Tunde Abimbola Cresent",7031070581,',
#  'Igun Primary School,Oredo,Tonee Global Resources,1st Floor Oladebo House 29 Ladipo Oluwole St. Lagos State ,7065016834,',
#  'Iguobazuwa  Grammar School,Ovia S/W,Charles Tempo Associates,"25, Adesuwa Girls Grammar School Rd",7035800638,',
#  'Iguomo Secondary School,Uhunmwonde,Royal Faboh Nig. Ltd.,"4, Oboh Str, Ikpoba Hill",8037267699,',
#  'Ihogbe College B/City,Oredo,Airoe Con. Company Ltd.,"130, New Lagos Road",8033724450,',
#  '"Ikabigbo Secondary School,  Ikabibgo (Lot: 2)",Estako West,New Prime Eng. Ltd.,,8023342004,',
#  '"Ikabigbo Secondary School, Ikabibgo (Lot: 3)",Etsako West,Tymdeen Nig Ltd.,"52, Ogunsola Estate, Lagos",8169229814,',
#  '"Ikabigbo Secondary School, Ikabibgo (Lot: 1)",Estako West,Shagman Nig. Ltd.,,8037811901,',
#  '"Ikpomaza Grammar School,  Okpilla (Lot: 2)",Etsako East,Contrad Invesment Ltd.,"272, Maiduguri Road, Kano",8034520490,',
#  '"Ikpomaza Grammar School, Okpella (Lot: 1)",Etsako East,Lavista Construction Company Ltd.,,8098748270,',
#  '"Imaguero College B/C Hall, Admin Block & Classrooms",Oredo,Revere Works W. Africa Ltd.,"100, Sapele Road, Benin City",8028187076,',
#  'Imaguero Senior College B/C Corper�s Lodge/Laboratories ,Oredo,Building Access./Warehouse ,"Kilometer 6, Sapele Rd. Benin City",8033744427,',
#  'Iuleha Grammar School,Owan West,A.O.Ohikhena& Ass. Ltd.,"4, Dio Obaseki Avenue",8078654178,',
#  '"Iviukwe Secondary School, Ivikwe, Fencing/External Works (Lot: 2) ",Etsako East,Amosim Projects Nig. Ltd.,"2, Ediale St, Btw Boundary Road",8036412226,',
#  '"Iviukwe Secondary School,Iviukwe (Lot: 1)",Estako East,Naboya Transport Line,"206, Benin-Auchi Road, Benin City",8086803300,',
#  'Iyamho Community Secondary School Iyamho (Fencing),Etsako West,Pa Etos Ltd.,"Plot 242 Buhari Way, C.R.D Abuja",8036404250,',
#  '"Iyamho Community Secondary School, Iyamho ",Etsako West,Pa Etos Nig. Ltd.,"Jima Plaza Plot 1267  A.B Way, Abuja",8036404250,',
#  'Iyekhei Girls Grammar School,Estako West,Kamuzu Nig. Ltd.,"7, Ihama Rd.",8033110044,',
#  'Iyekogba Grammar Schoolch,Oredo,K.G Int. Service Ltd.,"10, Omokhu St. D/Line P/H",8037311584,',
#  '"Iyoba College, Benin City",Oredo,Westfield Global Contr. Ltd.,"10, Harmony Plaza, Jadi Cds, Abuja",7035718577,',
#  'Izevbigie Primary School,Oredo,Ibrunat Int. Ltd. ,"22, Idahosa St, Off Mission Rd.",7038718246,',
#  '"Michael Imoudu College Of Physical Education, Afuze (Lots: 4 & 6)",Owan East,Gbogest Nig. Ltd.,"52,  Ihama Road, Gra, Benin City",8052562107,',
#  '"Model Secondary School, Edo South (New Era)",Oredo,Technova Contr. Nig. Ltd.,"12, Bobo Street, Abuja",8032011375,',
#  '"Model Secondary Schoolool, Edo Central",Esan S/E,Sincie Chiementir Int.,"Plot 45, Akanbi Oniter Close, Lagos",8039786138,',
#  '"Model Secondary Schoolool, Edo North",Estako West,Sincie Chiementir Int.,"Plot 45, Akanbi Oniter Close, Lagos",8039786138,"Terminated,Re-aWarded to A & K Const. Coy."',
#  '"Model Secondary School,Iyamho, Edo North",Edo North,A & K Const. Ltd.,"527, Shehu Yar\'adua, Kado District, Abuja",8079377443,',
#  '"Momodu College, Agbede (Lot: 1)",Etsako West,Dyke Zaria Ltd.,"Royal Palace, Ugbekpe-Ekperi",-,',
#  '"Momodu College, Agbede (Lot: 2)",Etsako West,Beniuos Nig. Ltd.,"6th, 5th Canan Lane",8033711191,',
#  'Niger College Benin City,Ikpoba-Okha,Rever (Wa) Works,"100, Sapele Road, Benin City",8028187076,',
#  'Oba Akenzua Secondary School (Lot: 2),Oredo,Glopet Nig. Ltd.,"14, Commercial Ave, Gra",8037244194,',
#  'Oba Akenzua Secondary School (Lot: 1),Oredo,Suyi Technico Com. Ltd.,"28, Zabayo Street, Benin City",8033382580,',
#  'Oba Ewuare Secondary School. Benin City,Oredo,Macpaul Constr. Com. Ltd.,"Suit 004,Charsti Plaza",8073987343,',
#  'Ogbe Primary School,Oredo,Tonee Global Resources Ltd.,"1st Floor, Oladapo House ",7065016834,',
#  'Oghada Grammar School Oghada (Lot: 2),Uhunmwode,Debve Sytems Ltd.,"36a, Elema Quarters, Gra",8035989485,',
#  '"Oghada Grammar School, Oghada (Lot: 1)",Uhunmwode,Dansu Enterprise,"1, Arapasowo Street, Ayeh-Lagos",8023081847,',
#  'Ogwa Grammar School,Esan West,Morifa Ltd. ,"20, Ihama Road",8078654178,',
#  'Okada Grammar School Okada (Lots: 1 & 2),Ovia Ne,El-Kapa Nig. Ltd.,"5, 2nd East Circular Rd, Off Sapele Rd, Benin City",8033564134,',
#  '"Okhuesan Secondary School, Okhuesan",Esan S/E,Bugabi Construction & Engineering Ltd.,"Plot 104c, Airport Rd, Warri, Delta State",8033429269,',
#  'Okpekpe Secondary School,Etsako East,Stalish Nig. Ltd.,"1a, Thomas Laniyen Street, Lagos",8022235131,',
#  '"Olodiama Primary School, Nikorogha (Lots: 1 & 2)",Ovia S/W,Pere-Ere Ltd.,,-,',
#  'Opoji Secondary Community School (Lots: 1 & 2),Esan Central,Godfrey Ehi Nig. Ltd.,"1, Royal Palace Rd.",-,',
#  'Opoji Secondary Community School (Lots: 3 & 4),Esan Central,Snobec Nig. Ltd.,"7, Ihama Rd.",8062906507,',
#  'Osemwende Secondary School Ohoghobi (Lot: 1),Ikpoba-Okha,If-Evan Cont. Venture,"7, Idehen Avenue, Off Siluko Road, Benin City",8037175204,',
#  'Osemwende Secondary School Ohoghobi (Lot: 2),Ikpoba-Okha,Osaeso Ltd.,"Adenomo Crescent, Etete",8063197837,',
#  '"Otugo Grammar School, Ake",Akoko-Edo,Kard Royal Gate Nig. Ltd.,"24, Agbonifo Street, Gra",7053585444,',
#  'Our Lady Of Fatima Colllege,Etsako West,Pa-Etos Ltd.,"Jima Plaza (3rd Floor ), Abuja",8036404250,',
#  'Our Lady Of Fatima College (Fencing),Etsako West,Pa Etos Ltd.,"Jima Plaza Plot 1267  A.B Way, Abuja",8036404250,',
#  'Our Lady Of Lourdes Grammar School,Esan N/E,Highbury Ventures World,"24, Eguavon Street, Benin City",8055674214,',
#  'Police Children School,Egor,Sunamo Investment Ltd.,"26, Eguadese Strret, Benin City",8023046205,',
#  'Siluko Grammar School,Egor,Brosmax Nig. Ltd. ,"28, Oke-Ogba , Airport Road",8033708475,',
#  '"Sobe High School, Sobe (Lots: 1 & 2)",Owan West,El-Kolo Associates,"63, Ekewan Rd, Benin City",8037255876,',
#  '"Sobe High School, Sobe (Lot: 3)",Owan West,Tara Nig. Ltd.,,8033018737 08055243870,',
#  '"Somorika Junior Secondary School, Somorika",Akoko-Edo,Aquachris Chemicals Nig. Ltd.,"10, Davidson, 2, Okorosa St, Asaba.",8037751107,',
#  'Somorika Senior Secondry,Akoko-Edo,Cornlawan Nig. Ltd.,"2, Lawani Street, Igarra",8035760328,',
#  '"St John\'s Model Secondary School, Fugar",Etsako Central,Cremona Construction Co.,"Plot 5a, Kadenda Ind. Layout, Kaduna",8058992057,',
#  '"St. Angela Grammar School, Uzairue",Etsako West,Pa-Etos Ltd. Abuja,"Jima Plaza (3rd Floor ), Abuja",8036404250,',
#  '"St. Jame\'s Grammar School, Afuze",Owan East,Tontime Tech. Ltd.,"28, Agwobasimwin  Road, Gra",8032278185,',
#  '"St. John Bosco Grammar School, Ubiaja",Esan S/E,Madona Org. Ltd.,"118, M.M. Way, Benin City",052-253127,',
#  'St. Maria Goretti Girls Grammar School,Ikpoba-Okha,Airoe Con. Company Ltd.,"130, New Lagos Road",8033724450,',
#  'St. Pauls Anglican Grammar School,Akoko-Edo,Charles Tempo Associates,"25, Adesuwa Girls Grammar School Rd",7035800638,',
#  '"St. Peter\'s Grammar School, Agenebode",Estako East,Nikaro Nig. Ltd.,"113, 2nd Cemetry Road",8034053471,',
#  '"St.Mary\'s Secondary School, Eme-Ora",Owan East,Tontime Tech. Ltd.,"28, Agwobasimwin  Road, Gra",8032278185,',
#  '"Supply Of 35,000 Units Of Single Seaters And   40,000 Units ",Selected Secondary Schools,Itex Furniture,"Plot 512, Creestal Lane",8034080256,',
#  '"Ugbeka College, Evboehiagae (Lot: 1)",Orhionmwon,S.Noma & Com. Ltd.,"Km 6, Benin-Sapele Road",-,',
#  '"Ugbeka College, Evboehiaghae (Lot: 2)",Orhionmwon,Sonhan Int. Ltd.,"157, Uselu Lagos Road, Benin City",-,',
#  '"Ugbeka College, Evboehiaghae (Lot: 3)",Orhionmwon,First Foundation & Gen. Works,"7, Ogbewe Street, Benin City",8033362955,',
#  '"Ughoton Secondary School, Ekenwan",Ovia North-East,Bronze & Stockwells,"24, Gaius Idubor Street",8054411754,',
#  '"Ugiomo Secondary School, Evboriaria",Ikpoba-Okha,Positive Ways Nig. Ltd.,"Offiah Plaza, New Lagos Road",8037005001,',
#  '"Ugo Grammar School, Ugo (Lot: 2)",Orhionmwon,Vito Concept Ltd.,"94, 2nd East Circular Road",8032728258,',
#  'Ugo Grammar School (Lot: 3),Orhionmwon,Edokpaigbe Nig. Ent.,"212a, Ugbowo Lagos Rd.",8023412771,',
#  '"Ujoelan Grammar School, Ekpoma",Esan West,Fuma & Sons Nig. Ltd.,"121, Benin-Auchi Road, Ekpoma",8057282260,',
#  '"Uku Secondary School, Iyuku (Lot: 1)",Etsako West,Contrad Investments Ltd.,"117b, Ezekiel Cresent, Off Awuyemi Rd.",8034520490,',
#  '"Uku Sec Commercial School, Iyuku (Lot: 2)",Etsako West,Okoebor & Sons Enterprise,"51, Ogboni Rd, Uromi, Edo State",8052700278,',
#  '"Uralo Grammar School, Iraokhor",Etsako Central,Pa-Etos Ltd.,"Jima Plaza, Plot 1267  A.B Way, Abuja",8036404250,',
#  '"Urhonigbe Grammar School, Urhonigbe",Orhionmwon,Osanabel Global Resources,"25, Evbiemwen St, Off Wire Road.",8057917022,',
#  'Uwa Primary School,Ikpoba-Okha,God\'s Vineyard Ent.,"46, Ugbor Rd.",8033050477,',
#  '"Uzebba Secondary School, Uzebba",Owan West,Sapakorp Ltd.,"17a, Warrack Road, Auchi",8033844834,',
#  'Western Boys High School,Ikpoba-Okha,Doma Industries Ltd.,"55, Edebiri Street, Off Ekenwan Rd",8056155701,']

# %%
from pyspark.context import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql import Row


#création de contexte SPark
sc = SparkContext.getOrCreate()

#création de la session Spark
spark = SparkSession.builder.getOrCreate()

#filtrage des noms contenants des mots clés
def filterWord(City):
    return ("@" in City) or ("/" not in City) == True \
            and len(City) > 0

 

#fonction de chargement de données
def loadData(path):
    rdd = sc.textFile("C://Users/carlyna.bondiombouy/Desktop/tmp/spark-docs/*.csv")\
            .flatMap(lambda lines : lines.lower().split())\
            .flatMap(lambda word : word.split(",")) \
            .flatMap(lambda word : word.split(".")) \
            .flatMap(lambda word : word.split(";")) \
            .flatMap(lambda word : word.split(":")) \
            .flatMap(lambda word : word.split("?")) \
            .flatMap(lambda word : word.split("!")) \
            .flatMap(lambda word : word.split("\"")) \
            .flatMap(lambda word : word.split("-")) \
            .flatMap(lambda word : word.split("\'"))\
            .filter(filterWord)\
            .map(lambda word : (word, 1)) \
            .reduceByKey( lambda count1, count2 : count1 + count2 ) \
            .map(lambda data : Row(label=data[0], length=len(data[0]), freq=data[1]))
    
    #return spark.createDataFrame(rdd)


#chargement des données
dataFrame = loadData("C:/Users/carlyna.bondiombouy/Desktop/tmp/spark-docs/*.csv")
print(dataFrame)
#print("le nombre total de mots est :", dataFrame.count())
# Out:
# None

# %%
from pyspark import  SparkContext
sc = SparkContext.getOrCreate()
text_file = sc.textFile("C://Users/carlyna.bondiombouy/Desktop/tmp/spark-docs/*.csv")
counts = text_file.flatMap(lambda line: line.split()) 
countsWord= counts.map(lambda word: (word, 1))#.cache()
reduceWord= countsWord.reduceByKey(lambda a, b: a + b)
#reduceWord.collect()
#sc.stop()
reduceWord.saveAsTextFile("C://Users/carlyna.bondiombouy/Desktop/tmp/TP_Spark/ls")

# %% [markdown]
# ___**Evaluating the benefit of parallelism**___
#
# Run the above example with one worker (no parallelism) and with several workers to assess the benefit of parallelism. The optimal number of workers for a standalone (single-node) Spark setup is the number of CPU cores. In MacOS, you can get the number of logical cores with the following bash command: *sysctl -n hw.ncpu*
#
# You can also get the current time in Python by calling the *time* function defined in the time Python package. If you do this before and after the call to *saveAsTextFile* and print the difference, you can get the elapsed time.
#
# Hint: You can define a Python script file to be executed automatically when pyspark is started, by setting the environment variable *PYTHONSTARTUP*.
#
# __Solution:__

# %%
import time
linesRDD = sc.textFile("C://Users/carlyna.bondiombouy/Desktop/tmp/spark-docs/*.csv")
wordsRDD = linesRDD.flatMap( lambda l: l.split(' ') )
wordsPairRDD = wordsRDD.map( lambda a: (a, 1) )
wordCount = wordsPairRDD.reduceByKey(lambda a, b: a + b)
t = time.time()
wordCount.saveAsTextFile("C://Users/carlyna.bondiombouy/Desktop/tmp/TP_Spark/output')
localtime = time.localtime(time.time())
print ("Local current time :", localtime)
//print ('Time elapsed: ' + str(time.time() - t))

# %% [markdown]
# ___**Filteng the result**___
#
# Another important RDD operation is *filter*. It returns an RDD composed only of those elements, for which is satisfied the condition defined in the (lambda) function that is passed as argument to the *filter* RDD method. When applying the *filter* operation, this function is evaluated for each element of the RDD and those elements, for which it returns *False*, are filtered out.
#
# Modify the above query to get the count only of the word “Spark”. Now that the final RDD contains just one element, it will be more convenient to just collect and print it instead of saving it as text file. The result must be: *('Spark', 1011)*. Think about where in the chain of RDD operations to place the filter, to achieve an optimal execution.
#
# __Solution (optimal):__

# %%
linesRDD = sc.textFile('/tmp/TP_Spark/spark-docs/*.md')
wordsRDD = linesRDD.flatMap( lambda l: l.split(' ') )
wordsRDD = wordsRDD.filter( lambda a: a == 'Spark' )
wordsPairRDD = wordsRDD.map( lambda a: (a, 1) )
wordCount = wordsPairRDD.reduceByKey(lambda a, b: a + b)
print wordCount.collect()

# %% [markdown]
# ### Advanced Exercise
#
# Let us assume the following scenario. A forum web application keeps log data about its posts in text files where a single record corresponds to one post and contains two fields about the post itself (timestamp and username) followed by a variable number of fields storing the key-words mentioned in the post (the left side of the example below). Our final goal is to find for each keyword the user who mentioned it most frequently (the right side of the example).
#
#
# *2014-12-13, alice, storage, cloud*
# *2014-12-22, bob, cloud, virtual, app*
# *2014-12-24, alice, cloud*
#
# -------->
#
# |**KW**  |**expert** |**freq** |
# |--------|-----------|---------|
# |cloud   |alice      |2        |
# |storage |storage    |1        |
# |virtual |virtual    |1        |
# |app     |app        |1        |
#
# You can find this example input dataset in the file posts_small.txt. The fields in the input file are comma-separated, without blank spaces.
#
# ___**First goal: get user-keyword pairs**___
#
# Read the input file and break down each line to a number of (user, keyword) pairs, so that the result is the dataset:
#
# $[$ ('alice', 'storage'), ('alice', 'cloud'),
#  ('bob', 'cloud'), ('bob', 'virtual'), ('bob', 'app'),
#  ('alice', 'cloud')$]$
#
# Hint: you can use for...in Python generator expressions within brackets to create pairs between one variable and each element of a sub-collection, e.g.:
#
# ```Python
# a = ['a', 'x', 'y', 'z']
# pairs_a = [ (a[0], w) for w in a[1:] ]
# print pairs_a
# [('a', 'x'), ('a', 'y'), ('a', 'z')]
# ```

# %%
rdd = sc.textFile('/tmp/TP_Spark/posts_small.txt')
rdd = rdd.map( lambda l: l.split(',') )
rdd = rdd.flatMap(lambda a: [ (a[1], w) for w in a[2:] ])
print rdd.collect()

# %% [markdown]
# ___**Count the occurences of each pair**___
#
# Apply the *map* and *reduceByKey* technique from the previous section to group by each (user, keyword) pair and count the occurence of each pair. The result should be:
#
# $[$(('bob', 'virtual'), 1), (('bob', 'cloud'), 1),
#  (('bob', 'app'), 1),
#  (('alice', 'cloud'), 2), (('alice', 'storage'), 1)$]$
#
# **Solution:**

# %%
rdd = rdd.map( lambda a: (a, 1) )
rdd = rdd.reduceByKey( lambda a, b: a + b )
print rdd.collect()

# %% [markdown]
# ___**Map by keywords**___
#
# In the above intermediate key-value set, each pair of user and keyword is taken as the key. This was important for the *reduceByKey* to return the number of times each user has mentioned each keyword. Now we need to group by keywords, so we need a map to transform the above dataset into another key-value RDD, where keywords are the keys and (user, count) pairs are the values. The result should be:
#
# $[$('virtual', ('bob', 1)), ('cloud', ('bob', 1)),
#  ('app', ('bob', 1)),
#  ('cloud', ('alice', 2)), ('storage', ('alice', 1))$]$
#
# **Solution:**

# %%
rdd = rdd.map( lambda a: (a[0][1], (a[0][0], a[1])) )
print rdd.collect()

# %% [markdown]
# ___**Final goal: keep only the winner**___
#
# Finally, we have to reduce by key, so as for each keyword to keep only that (user, count) value that maximizes the count. In our example, the set of all the (user, count) values, mapped to they *'cloud'*, should be reduced to only the pair *('alice', 2)*.
#
# ```Python
# a = 3
# sign_a = 1 if a >= 0 else -1
# print sign_a
#
# ```

# %%
rdd = rdd.reduceByKey( lambda a, b: b if b[1] > a[1] else a )
print rdd.collect()

# %% [markdown]
# ___**Rasing the scale**___
#
# Run the full query on the much larger dataset in the *posts_large.txt* file. Print also the execution time. Experiment with different levels of parallelism (e.g. with 1, 2 and 4 workers) to evaluate the benefits of parallel computing.
#
# **Solution:**

# %%
import time
rdd = sc.textFile('/tmp/TP_Spark/posts_large.txt')
rdd = rdd.map( lambda l: l.split(',') )
rdd = rdd.flatMap(lambda a: [ (a[1], w) for w in a[2:] ])
rdd = rdd.map( lambda a: (a, 1) )
rdd = rdd.reduceByKey( lambda a, b: a + b )
rdd = rdd.map( lambda a: (a[0][1], (a[0][0], a[1])) )
rdd = rdd.reduceByKey( lambda a, b: b if b[1] > a[1] else a )
t = time.time()
print rdd.collect()
print 'Time elapsed: ' + str(time.time() - t)

# %% [markdown]
# ___**Filter by particular keywords**___
#
# Find the top users of only the keywords in the list ('Spark', 'cloud', 'data', 'mining'). Think about where in the chain of RDD operations to place the filter operation, to achieve an optimal execution.
#
# __Solution (optimal):__

# %%
import time
kwlist = ('Spark', 'cloud', 'data', 'mining')
rdd = sc.textFile('/tmp/TP_Spark/posts_large.txt')
rdd = rdd.map( lambda l: l.split(',') )
rdd = rdd.flatMap(lambda a: [ (a[1], w) for w in a[2:] ])
rdd = rdd.filter( lambda a: a[1] in kwlist )
rdd = rdd.map( lambda a: (a, 1) )
rdd = rdd.reduceByKey( lambda a, b: a + b )
rdd = rdd.map( lambda a: (a[0][1], (a[0][0], a[1])) )
rdd = rdd.reduceByKey( lambda a, b: b if b[1] > a[1] else a )
t = time.time()
print rdd.collect()
print 'Time elapsed: ' + str(time.time() - t)
